# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Dump Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452088 entries, 0 to 452087
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    452088 non-null  object
#  1   Journey_day        452088 non-null  object
#  2   Airline            452088 non-null  object
#  3   Flight_code        452088 non-null  object
#  4   Class              452088 non-null  object
#  5   Source             452088 non-null  object
#  6   Departure          452088 non-null  object
#  7   Total_stops        452088 non-null  object
#  8   Arrival            452088 non-null  object
#  9   Destination        452088 non-null  object
#  10  Duration_in_hours  452088 non-null  float64
#  11  Days_left          452088 non-null  int64
#  12  Fare               452088 non-null  int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 44.8+ MB

# %%
df.describe()
# Out:
#        Duration_in_hours      Days_left           Fare
# count      452088.000000  452088.000000  452088.000000
# mean           12.349222      25.627902   22840.100890
# std             7.431478      14.300846   20307.963002
# min             0.750000       1.000000    1307.000000
# 25%             6.583300      13.000000    8762.750000
# 50%            11.333300      26.000000   13407.000000
# 75%            16.500000      38.000000   35587.000000
# max            43.583300      50.000000  143019.000000

# %%
df2=df

# %%
def pie_plots(column, title):
    counts = df[column].value_counts()

    # Create the pie chart
    fig, ax = plt.subplots()
    pie = ax.pie(counts,labels= counts.index, autopct='%1.1f%%', 
                 wedgeprops={ 'linewidth' : 2, 'edgecolor' : 'white' },
                 startangle=150,labeldistance=1.1)
    # Add a circle at the center of the chart to create the donut shape
    center_circle = plt.Circle((0, 0), 0.8, fc='white')
    fig.gca().add_artist(center_circle)

    plt.text(0, 0, column, ha='center', va='center', fontsize=10)
    plt.title(title, fontsize=18)
    # Show the plot
    plt.show()

# %%
plt.figure(figsize=(20,8))
pie_plots('Airline', 'Airline Market Share')
pie_plots('Source', 'Flights from Source City')

# %%
pie_plots('Destination', 'Flights to Destination City')
pie_plots('Arrival', 'Arrival Time')

# %%
df['Date_of_journey']= pd.to_datetime(df['Date_of_journey'])

# %%
df.drop('Flight_code',axis=1,inplace = True)

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x='Airline',y='Fare',hue="Class",data=df.sort_values("Fare")).set_title('Airline prices based on the class and company',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Airline prices based on the class and company')

# %%
# Does price vary with Airlines?

# %%
fig, axs = plt.subplots (1, 2, gridspec_kw={'width_ratios': [5, 3]}, figsize=(25, 5))
sns.violinplot(y = "Fare", x = "Airline",data = df.loc[df["Class"]=='Economy'].sort_values("Fare", ascending = False), kind="boxen", ax=axs[0])
axs[0].set_title("Airline prices based on companies for economy tickets",fontsize=20)
sns.violinplot(y = "Fare", x = "Airline",data = df.loc[df["Class"]=='Business'].sort_values("Fare", ascending = False), kind="boxen", ax=axs[1])
axs[1].set_title("Airline prices based on companies for business tickets",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Airline prices based on companies for business tickets')

# %% [markdown]
# # Prices to days left

# %%
df_temp = df.groupby(['Days_left'])['Fare'].mean().reset_index()

plt.figure(figsize=(15,6))
ax = sns.scatterplot(x="Days_left", y="Fare", data=df_temp).set_title("Average prices depending on the days left",fontsize=15)

# %%
sns.barplot(y='Fare',x='Days_left',data=df)
# Out:
# <Axes: xlabel='Days_left', ylabel='Fare'>

# %%
sns.scatterplot(y='Fare',x='Days_left',data=df)
# Out:
# <Axes: xlabel='Days_left', ylabel='Fare'>

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='Date_of_journey',y='Fare',data=df)
# Out:
# <Axes: xlabel='Date_of_journey', ylabel='Fare'>

# %% [markdown]
# # Flight Timing and Prices

# %%
plt.figure(figsize = (18,5))
plt.subplot(1,2,1)
sns.boxplot(data=df, y="Fare", x="Departure",showfliers=False).set_title("Airline prices based on the departure time",fontsize=15)
plt.subplot(1,2,2)
sns.boxplot(data=df, y="Fare", x="Arrival",showfliers=False).set_title("Airline prices based on the arrival time",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Airline prices based on the arrival time')

# %%
dummy = pd.get_dummies(df[['Journey_day','Airline','Class','Source','Departure','Total_stops','Arrival','Destination']])

# %%
dummy
# Out:
#         Journey_day_Friday  Journey_day_Monday  Journey_day_Saturday  \
# 0                        0                   1                     0
# 1                        0                   1                     0
# 2                        0                   1                     0
# 3                        0                   1                     0
# 4                        0                   1                     0
# ...                    ...                 ...                   ...
# 452083                   0                   1                     0
# 452084                   0                   1                     0
# 452085                   0                   1                     0
# 452086                   0                   1                     0
# 452087                   0                   1                     0
#
#         Journey_day_Sunday  Journey_day_Thursday  Journey_day_Tuesday  \
# 0                        0                     0                    0
# 1                        0                     0                    0
# 2                        0                     0                    0
# 3                        0                     0                    0
# 4                        0                     0                    0
# ...                    ...                   ...                  ...
# 452083                   0                     0                    0
# 452084                   0                     0                    0
# 452085                   0                     0                    0
# 452086                   0                     0                    0
# 452087                   0                     0                    0
#
#         Journey_day_Wednesday  Airline_Air India  Airline_AirAsia  \
# 0                           0                  0                0
# 1                           0                  0                0
# 2                           0                  0                0
# 3                           0                  0                0
# 4                           0                  1                0
# ...                       ...                ...              ...
# 452083                      0                  0                0
# 452084                      0                  0                0
# 452085                      0                  0                0
# 452086                      0                  0                0
# 452087                      0                  0                0
#
#         Airline_AkasaAir  ...  Arrival_6 AM - 12 PM  Arrival_After 6 PM  \
# 0                      0  ...                     0                   1
# 1                      0  ...                     0                   0
# 2                      0  ...                     0                   0
# 3                      0  ...                     0                   1
# 4                      0  ...                     0                   1
# ...                  ...  ...                   ...                 ...
# 452083                 0  ...                     0                   1
# 452084                 0  ...                     0                   0
# 452085                 0  ...                     0                   0
# 452086                 0  ...                     0                   1
# 452087                 0  ...                     0                   1
#
#         Arrival_Before 6 AM  Destination_Ahmedabad  Destination_Bangalore  \
# 0                         0                      0                      0
# 1                         1                      0                      0
# 2                         1                      0                      0
# 3                         0                      0                      0
# 4                         0                      0                      0
# ...                     ...                    ...                    ...
# 452083                    0                      0                      0
# 452084                    0                      0                      0
# 452085                    0                      0                      0
# 452086                    0                      0                      0
# 452087                    0                      0                      0
#
#         Destination_Chennai  Destination_Delhi  Destination_Hyderabad  \
# 0                         0                  0                      0
# 1                         0                  0                      0
# 2                         0                  0                      0
# 3                         0                  0                      0
# 4                         0                  0                      0
# ...                     ...                ...                    ...
# 452083                    1                  0                      0
# 452084                    1                  0                      0
# 452085                    1                  0                      0
# 452086                    1                  0                      0
# 452087                    1                  0                      0
#
#         Destination_Kolkata  Destination_Mumbai
# 0                         0                   1
# 1                         0                   1
# 2                         0                   1
# 3                         0                   1
# 4                         0                   1
# ...                     ...                 ...
# 452083                    0                   0
# 452084                    0                   0
# 452085                    0                   0
# 452086                    0                   0
# 452087                    0                   0
#
# [452088 rows x 45 columns]

# %%
df.drop(['Journey_day','Airline','Class','Source','Departure','Total_stops','Arrival','Destination'],axis=1,inplace=True)

# %%
df
# Out:
#        Date_of_journey  Duration_in_hours  Days_left   Fare
# 0           2023-01-16             2.0833          1   5335
# 1           2023-01-16             2.3333          1   5899
# 2           2023-01-16             2.1667          1   5801
# 3           2023-01-16             2.0833          1   5794
# 4           2023-01-16             2.1667          1   5955
# ...                ...                ...        ...    ...
# 452083      2023-03-06            13.0833         50  65028
# 452084      2023-03-06            11.2500         50  69254
# 452085      2023-03-06            11.2500         50  69254
# 452086      2023-03-06            11.1667         50  72980
# 452087      2023-03-06            11.1667         50  72980
#
# [452088 rows x 4 columns]

# %%
df1=df

# %%
df['Journey_Month']= df['Date_of_journey'].dt.strftime('%b')

# %%
# sns.scatterplot(y='Fare',x='Days_left',hue='Journey_Month',data=df)

# %%
df = pd.concat([df,dummy],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452088 entries, 0 to 452087
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date_of_journey         452088 non-null  datetime64[ns]
#  1   Duration_in_hours       452088 non-null  float64
#  2   Days_left               452088 non-null  int64
#  3   Fare                    452088 non-null  int64
#  4   Journey_Month           452088 non-null  object
#  5   Journey_day_Friday      452088 non-null  uint8
#  6   Journey_day_Monday      452088 non-null  uint8
#  7   Journey_day_Saturday    452088 non-null  uint8
#  8   Journey_day_Sunday      452088 non-null  uint8
#  9   Journey_day_Thursday    452088 non-null  uint8
#  10  Journey_day_Tuesday     452088 non-null  uint8
#  11  Journey_day_Wednesday   452088 non-null  uint8
#  12  Airline_Air India       452088 non-null  uint8
#  13  Airline_AirAsia         452088 non-null  uint8
#  14  Airline_AkasaAir        452088 non-null  uint8
#  15  Airline_AllianceAir     452088 non-null  uint8
#  16  Airline_GO FIRST        452088 non-null  uint8
#  17  Airline_Indigo          452088 non-null  uint8
#  18  Airline_SpiceJet        452088 non-null  uint8
#  19  Airline_StarAir         452088 non-null  uint8
#  20  Airline_Vistara         452088 non-null  uint8
#  21  Class_Business          452088 non-null  uint8
#  22  Class_Economy           452088 non-null  uint8
#  23  Class_First             452088 non-null  uint8
#  24  Class_Premium Economy   452088 non-null  uint8
#  25  Source_Ahmedabad        452088 non-null  uint8
#  26  Source_Bangalore        452088 non-null  uint8
#  27  Source_Chennai          452088 non-null  uint8
#  28  Source_Delhi            452088 non-null  uint8
#  29  Source_Hyderabad        452088 non-null  uint8
#  30  Source_Kolkata          452088 non-null  uint8
#  31  Source_Mumbai           452088 non-null  uint8
#  32  Departure_12 PM - 6 PM  452088 non-null  uint8
#  33  Departure_6 AM - 12 PM  452088 non-null  uint8
#  34  Departure_After 6 PM    452088 non-null  uint8
#  35  Departure_Before 6 AM   452088 non-null  uint8
#  36  Total_stops_1-stop      452088 non-null  uint8
#  37  Total_stops_2+-stop     452088 non-null  uint8
#  38  Total_stops_non-stop    452088 non-null  uint8
#  39  Arrival_12 PM - 6 PM    452088 non-null  uint8
#  40  Arrival_6 AM - 12 PM    452088 non-null  uint8
#  41  Arrival_After 6 PM      452088 non-null  uint8
#  42  Arrival_Before 6 AM     452088 non-null  uint8
#  43  Destination_Ahmedabad   452088 non-null  uint8
#  44  Destination_Bangalore   452088 non-null  uint8
#  45  Destination_Chennai     452088 non-null  uint8
#  46  Destination_Delhi       452088 non-null  uint8
#  47  Destination_Hyderabad   452088 non-null  uint8
#  48  Destination_Kolkata     452088 non-null  uint8
#  49  Destination_Mumbai      452088 non-null  uint8
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1), uint8(45)
# memory usage: 36.6+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
#Case 1: Fare and Date of Journey

# %%
df['Date_of_journey_new']=df['Date_of_journey'].apply(lambda x: x.to_pydatetime().toordinal())

# %%
from datetime import datetime

# %%
# df['Date_of_journey_new2']=datetime.strptime(df['Date_of_journey'],"%Y-%m-%d")

# %%
y= df['Fare']

# %%
x=df['Date_of_journey_new']

# %%
X=sm.add_constant(x)
model=sm.OLS(y,X)
results =model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     3516.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:35   Log-Likelihood:            -5.1239e+06
# No. Observations:              452088   AIC:                         1.025e+07
# Df Residuals:                  452086   BIC:                         1.025e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                9.216e+07   1.55e+06     59.313      0.000    8.91e+07    9.52e+07
# Date_of_journey_new  -124.7540      2.104    -59.298      0.000    -128.877    -120.631
# ==============================================================================
# Omnibus:                    86116.848   Durbin-Watson:                   0.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144093.047
# Skew:                           1.324   Prob(JB):                         0.00
# Kurtosis:                       3.802   Cond. No.                     3.81e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.81e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(df['Date_of_journey_new'], df['Fare'])

# %% [markdown]
# # Using ARIMA to Observe

# %%
# df2=df1

# %%
# df2.set_index('Date_of_journey',inplace=True)

# %%
# arima_model = sm.tsa.ARIMA(df2['Fare'], order=(1, 0, 0)).fit()

# %%
# forecast_values = arima_model.forecast(steps=3)

# %%
# forecast_df = pd.DataFrame(forecast_values, columns=['Fare'], index=pd.date_range(start=df.index[-1], periods=3, closed='right'))

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(df2.index, df2['Fare'], label='Original Data')
# plt.plot(forecast_df.index, forecast_df['Fare'], label='Forecasted Values', linestyle='dashed')
# plt.xlabel('Timestamp')
# plt.ylabel('Price')
# plt.title('ARIMA Forecasting')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# # Using SARIMA

# %%
# sarima_model = sm.tsa.SARIMAX(df2['Fare'], order=(1, 0, 0), seasonal_order=(1, 1, 1, 7)).fit()

# %%
# # Forecast future values
# forecast_values = sarima_model.forecast(steps=3)  # Forecasting 3 steps ahead

# # Create DataFrame for the forecasted values
# forecast_df = pd.DataFrame(forecast_values, columns=['Fare'], index=pd.date_range(start=df2.index[-1], periods=3, freq='D'))

# # Plot the original data and the forecasted values
# plt.figure(figsize=(10, 6))
# plt.plot(df.index, df2['Fare'], label='Original Data')
# plt.plot(forecast_df.index, forecast_df['Fare'], label='Forecasted Values', linestyle='dashed')
# plt.xlabel('Timestamp')
# plt.ylabel('Price')
# plt.title('SARIMA Forecasting')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# # Linear Regression

# %%
reg = LinearRegression()

# %%
y1= df['Fare']

# %%
x1=df['Date_of_journey_new'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.33, random_state=42)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = reg.predict(X_test)

# %%
plt.scatter(y_test,pred)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 16546.923209144556
# MSE: 408696643.1785446
# RMSE: 20216.247010227802

# %% [markdown]
# # Checking with Days Left and Fare

# %%
x2= df2['Days_left'].values.reshape(-1,1)
y2=df2['Fare']

# %%
X_train, X_test, y_train, y_test = train_test_split(x2, y2, test_size=0.33, random_state=42)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = reg.predict(X_test)

# %%
plt.scatter(y_test,pred)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 16546.92320914585
# MSE: 408696643.17854834
# RMSE: 20216.247010227897

# %% [markdown]
# # Running all the variables once

# %%
y3= df['Fare']
x3= df.drop(['Fare','Date_of_journey','Days_left','Journey_Month'],axis=1)

# %%
X = sm.add_constant(x3)

# Fit the model
model = sm.OLS(y3, X)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:45   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X = sm.add_constant(x3)
for i in X.columns:
    model=sm.OLS(y3,X[i])
    result=model.fit()
    print(f"Summary for {i}:\n{results.summary()}\n")
# Out:
# Summary for const:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:45   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Duration_in_hours:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:45   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary for Journey_day_Friday:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:46   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Journey_day_Monday:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:46   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary for Journey_day_Saturday:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:46   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Journey_day_Sunday:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:46   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary for Journey_day_Thursday:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:46   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Journey_day_Tuesday:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:46   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# ...
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Destination_Mumbai:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:51   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary for Date_of_journey_new:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:51   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   4.389e+07   2.29e+05    191.681      0.000    4.34e+07    4.43e+07
# Duration_in_hours        -23.5626      2.079    -11.332      0.000     -27.638     -19.487
# Journey_day_Friday       6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Monday       6.27e+06   3.27e+04    191.683      0.000    6.21e+06    6.33e+06
# Journey_day_Saturday     6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Journey_day_Sunday      6.271e+06   3.27e+04    191.689      0.000    6.21e+06    6.33e+06
# Journey_day_Thursday     6.27e+06   3.27e+04    191.671      0.000    6.21e+06    6.33e+06
# Journey_day_Tuesday      6.27e+06   3.27e+04    191.680      0.000    6.21e+06    6.33e+06
# Journey_day_Wednesday    6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Airline_Air India       4.875e+06   2.54e+04    191.619      0.000    4.83e+06    4.93e+06
# Airline_AirAsia         4.873e+06   2.54e+04    191.542      0.000    4.82e+06    4.92e+06
# Airline_AkasaAir        4.878e+06   2.54e+04    191.714      0.000    4.83e+06    4.93e+06
# Airline_AllianceAir     4.877e+06   2.54e+04    191.677      0.000    4.83e+06    4.93e+06
# Airline_GO FIRST        4.876e+06   2.54e+04    191.642      0.000    4.83e+06    4.93e+06
# Airline_Indigo          4.876e+06   2.54e+04    191.635      0.000    4.83e+06    4.93e+06
# Airline_SpiceJet        4.876e+06   2.54e+04    191.643      0.000    4.83e+06    4.93e+06
# Airline_StarAir         4.881e+06   2.55e+04    191.726      0.000    4.83e+06    4.93e+06
# Airline_Vistara         4.879e+06   2.54e+04    191.775      0.000    4.83e+06    4.93e+06
# Class_Business          1.099e+07   5.72e+04    191.934      0.000    1.09e+07    1.11e+07
# Class_Economy           1.095e+07   5.72e+04    191.234      0.000    1.08e+07    1.11e+07
# Class_First             1.101e+07   5.72e+04    192.262      0.000    1.09e+07    1.11e+07
# Class_Premium Economy   1.095e+07   5.72e+04    191.285      0.000    1.08e+07    1.11e+07
# Source_Ahmedabad         6.27e+06   3.27e+04    191.660      0.000    6.21e+06    6.33e+06
# Source_Bangalore         6.27e+06   3.27e+04    191.687      0.000    6.21e+06    6.33e+06
# Source_Chennai           6.27e+06   3.27e+04    191.679      0.000    6.21e+06    6.33e+06
# Source_Delhi            6.268e+06   3.27e+04    191.620      0.000     6.2e+06    6.33e+06
# Source_Hyderabad        6.269e+06   3.27e+04    191.654      0.000    6.21e+06    6.33e+06
# Source_Kolkata          6.274e+06   3.27e+04    191.781      0.000    6.21e+06    6.34e+06
# Source_Mumbai            6.27e+06   3.27e+04    191.685      0.000    6.21e+06    6.33e+06
# Departure_12 PM - 6 PM  1.097e+07   5.72e+04    191.683      0.000    1.09e+07    1.11e+07
# Departure_6 AM - 12 PM  1.097e+07   5.72e+04    191.682      0.000    1.09e+07    1.11e+07
# Departure_After 6 PM    1.097e+07   5.72e+04    191.686      0.000    1.09e+07    1.11e+07
# Departure_Before 6 AM   1.097e+07   5.72e+04    191.673      0.000    1.09e+07    1.11e+07
# Total_stops_1-stop      1.463e+07   7.63e+04    191.710      0.000    1.45e+07    1.48e+07
# Total_stops_2+-stop     1.464e+07   7.63e+04    191.739      0.000    1.45e+07    1.48e+07
# Total_stops_non-stop    1.462e+07   7.63e+04    191.594      0.000    1.45e+07    1.48e+07
# Arrival_12 PM - 6 PM    1.097e+07   5.72e+04    191.698      0.000    1.09e+07    1.11e+07
# Arrival_6 AM - 12 PM    1.097e+07   5.72e+04    191.667      0.000    1.09e+07    1.11e+07
# Arrival_After 6 PM      1.097e+07   5.72e+04    191.696      0.000    1.09e+07    1.11e+07
# Arrival_Before 6 AM     1.097e+07   5.72e+04    191.664      0.000    1.09e+07    1.11e+07
# Destination_Ahmedabad   6.268e+06   3.27e+04    191.617      0.000     6.2e+06    6.33e+06
# Destination_Bangalore   6.271e+06   3.27e+04    191.693      0.000    6.21e+06    6.33e+06
# Destination_Chennai     6.271e+06   3.27e+04    191.703      0.000    6.21e+06    6.34e+06
# Destination_Delhi       6.269e+06   3.27e+04    191.637      0.000     6.2e+06    6.33e+06
# Destination_Hyderabad   6.269e+06   3.27e+04    191.651      0.000    6.21e+06    6.33e+06
# Destination_Kolkata     6.273e+06   3.27e+04    191.770      0.000    6.21e+06    6.34e+06
# Destination_Mumbai      6.271e+06   3.27e+04    191.695      0.000    6.21e+06    6.33e+06
# Date_of_journey_new     -155.8352      0.813   -191.624      0.000    -157.429    -154.241
# ==============================================================================
# Omnibus:                   124971.480   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936641.470
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.46e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # Now selecting few of the variables and running one by one

# %%
# Journey Days in first Case

# %%
y4= df['Fare']
x4= df[['Date_of_journey_new','Journey_day_Sunday','Journey_day_Monday','Journey_day_Tuesday','Journey_day_Wednesday','Journey_day_Thursday','Journey_day_Friday','Journey_day_Saturday']]

# %%
X = sm.add_constant(x4)

# Fit the model
model = sm.OLS(y4, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     528.8
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:51   Log-Likelihood:            -5.1238e+06
# No. Observations:              452088   AIC:                         1.025e+07
# Df Residuals:                  452080   BIC:                         1.025e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  8.192e+07   1.37e+06     59.957      0.000    7.92e+07    8.46e+07
# Date_of_journey_new    -126.7353      2.114    -59.942      0.000    -130.879    -122.591
# Journey_day_Sunday      1.17e+07   1.95e+05     59.958      0.000    1.13e+07    1.21e+07
# Journey_day_Monday      1.17e+07   1.95e+05     59.958      0.000    1.13e+07    1.21e+07
# Journey_day_Tuesday     1.17e+07   1.95e+05     59.956      0.000    1.13e+07    1.21e+07
# Journey_day_Wednesday   1.17e+07   1.95e+05     59.958      0.000    1.13e+07    1.21e+07
# Journey_day_Thursday    1.17e+07   1.95e+05     59.953      0.000    1.13e+07    1.21e+07
# Journey_day_Friday      1.17e+07   1.95e+05     59.956      0.000    1.13e+07    1.21e+07
# Journey_day_Saturday    1.17e+07   1.95e+05     59.957      0.000    1.13e+07    1.21e+07
# ==============================================================================
# Omnibus:                    86138.441   Durbin-Watson:                   0.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144145.546
# Skew:                           1.324   Prob(JB):                         0.00
# Kurtosis:                       3.801   Cond. No.                     1.65e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.03e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X_train, X_test, y_train, y_test = train_test_split(x4, y4, test_size=0.33, random_state=42)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=reg.predict(X_test)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 16542.826811867417
# MSE: 408570344.89731425
# RMSE: 20213.123086186217

# %%
# Scaling the Independent Variable

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=reg.predict(X_test)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 839178025690.9407
# MSE: 1.085801927078069e+24
# RMSE: 1042018199014.8104

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 16543.093490683023
# MSE: 408580623.0747959
# RMSE: 20213.37732974863

# %%
# Removing date of Journet and compute

# %%
y5= df['Fare']
x5= df[['Journey_day_Sunday','Journey_day_Monday','Journey_day_Tuesday','Journey_day_Wednesday','Journey_day_Thursday','Journey_day_Friday','Journey_day_Saturday']]

# %%
X = sm.add_constant(x5)

# Fit the model
model = sm.OLS(y5, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     15.26
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           4.22e-20
# Time:                        18:10:53   Log-Likelihood:            -5.1256e+06
# No. Observations:              452088   AIC:                         1.025e+07
# Df Residuals:                  452080   BIC:                         1.025e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -6.151e+13    7.6e+13     -0.810      0.418    -2.1e+14    8.74e+13
# Journey_day_Sunday     6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# Journey_day_Monday     6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# Journey_day_Tuesday    6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# Journey_day_Wednesday  6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# Journey_day_Thursday   6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# Journey_day_Friday     6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# Journey_day_Saturday   6.151e+13    7.6e+13      0.810      0.418   -8.74e+13     2.1e+14
# ==============================================================================
# Omnibus:                    88117.537   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149283.599
# Skew:                           1.335   Prob(JB):                         0.00
# Kurtosis:                       3.895   Cond. No.                     7.61e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.93e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
#  NO particular signifance

# %%
X_train, X_test, y_train, y_test = train_test_split(x5, y5, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 16606.58366145938
# MSE: 411896972.57036954
# RMSE: 20295.24507293197

# %%
# removing date of Journey and compute

# %%
y6= df['Fare']
x6= df.drop(['Fare','Date_of_journey','Date_of_journey_new','Journey_Month'],axis=1)

# %%
X = sm.add_constant(x6)

# Fit the model
model = sm.OLS(y6, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:55   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                  -1.521e+12   6.03e+13     -0.025      0.980    -1.2e+14    1.17e+14
# Duration_in_hours        -23.5623      2.079    -11.331      0.000     -27.638     -19.487
# Days_left               -155.8352      0.813   -191.623      0.000    -157.429    -154.241
# Journey_day_Friday     -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Journey_day_Monday     -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Journey_day_Saturday   -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Journey_day_Sunday     -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Journey_day_Thursday   -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Journey_day_Tuesday    -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Journey_day_Wednesday  -1.412e+11    5.6e+12     -0.025      0.980   -1.11e+13    1.08e+13
# Airline_Air India       1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_AirAsia         1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_AkasaAir        1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_AllianceAir     1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_GO FIRST        1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_Indigo          1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_SpiceJet        1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_StarAir         1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Airline_Vistara         1.078e+11   4.28e+12      0.025      0.980   -8.27e+12    8.49e+12
# Class_Business          3.187e+11   1.26e+13      0.025      0.980   -2.45e+13    2.51e+13
# Class_Economy           3.187e+11   1.26e+13      0.025      0.980   -2.45e+13    2.51e+13
# Class_First             3.187e+11   1.26e+13      0.025      0.980   -2.45e+13    2.51e+13
# Class_Premium Economy   3.187e+11   1.26e+13      0.025      0.980   -2.45e+13    2.51e+13
# Source_Ahmedabad        1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Source_Bangalore        1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Source_Chennai          1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Source_Delhi            1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Source_Hyderabad        1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Source_Kolkata          1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Source_Mumbai           1.954e+11   7.75e+12      0.025      0.980    -1.5e+13    1.54e+13
# Departure_12 PM - 6 PM  2.762e+11    1.1e+13      0.025      0.980   -2.12e+13    2.18e+13
# Departure_6 AM - 12 PM  2.762e+11    1.1e+13      0.025      0.980   -2.12e+13    2.18e+13
# Departure_After 6 PM    2.762e+11    1.1e+13      0.025      0.980   -2.12e+13    2.18e+13
# Departure_Before 6 AM   2.762e+11    1.1e+13      0.025      0.980   -2.12e+13    2.18e+13
# Total_stops_1-stop      4.245e+11   1.68e+13      0.025      0.980   -3.26e+13    3.34e+13
# Total_stops_2+-stop     4.245e+11   1.68e+13      0.025      0.980   -3.26e+13    3.34e+13
# Total_stops_non-stop    4.245e+11   1.68e+13      0.025      0.980   -3.26e+13    3.34e+13
# Arrival_12 PM - 6 PM    2.675e+11   1.06e+13      0.025      0.980   -2.05e+13    2.11e+13
# Arrival_6 AM - 12 PM    2.675e+11   1.06e+13      0.025      0.980   -2.05e+13    2.11e+13
# Arrival_After 6 PM      2.675e+11   1.06e+13      0.025      0.980   -2.05e+13    2.11e+13
# Arrival_Before 6 AM     2.675e+11   1.06e+13      0.025      0.980   -2.05e+13    2.11e+13
# Destination_Ahmedabad   7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# Destination_Bangalore   7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# Destination_Chennai     7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# Destination_Delhi       7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# Destination_Hyderabad   7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# Destination_Kolkata     7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# Destination_Mumbai      7.207e+10   2.86e+12      0.025      0.980   -5.53e+12    5.68e+12
# ==============================================================================
# Omnibus:                   124971.088   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936638.690
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.66e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Removed Arline Air India and Destination Ahmedabad

# %%
y7= df['Fare']
x7= df.drop(['Fare','Date_of_journey','Date_of_journey_new','Journey_Month','Airline_Air India','Destination_Ahmedabad'],axis=1)
X = sm.add_constant(x7)

# Fit the model
model = sm.OLS(y7, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 6.776e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:10:57   Log-Likelihood:            -4.6908e+06
# No. Observations:              452088   AIC:                         9.382e+06
# Df Residuals:                  452048   BIC:                         9.382e+06
# Df Model:                          39
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   -9.68e+11   5.94e+13     -0.016      0.987   -1.17e+14    1.16e+14
# Duration_in_hours        -23.5624      2.079    -11.331      0.000     -27.638     -19.487
# Days_left               -155.8352      0.813   -191.622      0.000    -157.429    -154.241
# Journey_day_Friday     -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Journey_day_Monday     -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Journey_day_Saturday   -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Journey_day_Sunday     -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Journey_day_Thursday   -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Journey_day_Tuesday    -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Journey_day_Wednesday  -8.734e+10   5.36e+12     -0.016      0.987   -1.06e+13    1.04e+13
# Airline_AirAsia        -2016.6582     68.737    -29.339      0.000   -2151.381   -1881.935
# Airline_AkasaAir        2384.6610    171.117     13.936      0.000    2049.276    2720.046
# Airline_AllianceAir     1729.9117    393.924      4.391      0.000     957.832    2501.991
# Airline_GO FIRST         610.2197     80.654      7.566      0.000     452.140     768.299
# Airline_Indigo           287.3669     44.415      6.470      0.000     200.315     374.419
# Airline_SpiceJet         641.3304    105.293      6.091      0.000     434.960     847.701
# Airline_StarAir         5488.3856    986.866      5.561      0.000    3554.159    7422.612
# Airline_Vistara         3932.9968     30.066    130.813      0.000    3874.069    3991.925
# Class_Business          2.262e+11   1.39e+13      0.016      0.987    -2.7e+13    2.74e+13
# Class_Economy           2.262e+11   1.39e+13      0.016      0.987    -2.7e+13    2.74e+13
# Class_First             2.262e+11   1.39e+13      0.016      0.987    -2.7e+13    2.74e+13
# Class_Premium Economy   2.262e+11   1.39e+13      0.016      0.987    -2.7e+13    2.74e+13
# Source_Ahmedabad        1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Source_Bangalore        1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Source_Chennai          1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Source_Delhi            1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Source_Hyderabad        1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Source_Kolkata          1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Source_Mumbai           1.382e+11   8.49e+12      0.016      0.987   -1.65e+13    1.68e+13
# Departure_12 PM - 6 PM  1.972e+11   1.21e+13      0.016      0.987   -2.35e+13    2.39e+13
# Departure_6 AM - 12 PM  1.972e+11   1.21e+13      0.016      0.987   -2.35e+13    2.39e+13
# Departure_After 6 PM    1.972e+11   1.21e+13      0.016      0.987   -2.35e+13    2.39e+13
# Departure_Before 6 AM   1.972e+11   1.21e+13      0.016      0.987   -2.35e+13    2.39e+13
# Total_stops_1-stop      3.012e+11   1.85e+13      0.016      0.987   -3.59e+13    3.65e+13
# Total_stops_2+-stop     3.012e+11   1.85e+13      0.016      0.987   -3.59e+13    3.65e+13
# Total_stops_non-stop    3.012e+11   1.85e+13      0.016      0.987   -3.59e+13    3.65e+13
# Arrival_12 PM - 6 PM    1.926e+11   1.18e+13      0.016      0.987    -2.3e+13    2.34e+13
# Arrival_6 AM - 12 PM    1.926e+11   1.18e+13      0.016      0.987    -2.3e+13    2.34e+13
# Arrival_After 6 PM      1.926e+11   1.18e+13      0.016      0.987    -2.3e+13    2.34e+13
# Arrival_Before 6 AM     1.926e+11   1.18e+13      0.016      0.987    -2.3e+13    2.34e+13
# Destination_Bangalore   2451.9724     47.788     51.309      0.000    2358.310    2545.635
# Destination_Chennai     2862.9365     49.775     57.518      0.000    2765.380    2960.493
# Destination_Delhi        490.2421     47.651     10.288      0.000     396.847     583.637
# Destination_Hyderabad   1185.6502     48.937     24.228      0.000    1089.735    1281.565
# Destination_Kolkata     4975.0918     50.195     99.116      0.000    4876.711    5073.472
# Destination_Mumbai      2554.2610     46.627     54.780      0.000    2462.873    2645.649
# ==============================================================================
# Omnibus:                   124970.898   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           936661.821
# Skew:                           1.129   Prob(JB):                         0.00
# Kurtosis:                       9.680   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.66e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X_train, X_test, y_train, y_test = train_test_split(x7, y7, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 5126.444480193042
# MSE: 60084736.6044507
# RMSE: 7751.434486883747

# %%
#We observe a significant decrease in RMSE and MSE

# %%
# plt.scatter(y_test,pred)
# sns.distplot((y_test-pred),bins=100);

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=df,x='Duration_in_hours',y='Fare',hue='Class_Business',palette='hls')
# Out:
# <Axes: xlabel='Duration_in_hours', ylabel='Fare'>

# %%
a={'Model Name':[], 'Mean_Absolute_Error_MAE':[] ,'Adj_R_Square':[] ,'Root_Mean_Squared_Error_RMSE':[] ,'Mean_Absolute_Percentage_Error_MAPE':[] ,'Mean_Squared_Error_MSE':[] ,'Root_Mean_Squared_Log_Error_RMSLE':[] ,'R2_score':[]}
Results=pd.DataFrame(a)
Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, Mean_Absolute_Error_MAE, Adj_R_Square, Root_Mean_Squared_Error_RMSE, Mean_Absolute_Percentage_Error_MAPE, Mean_Squared_Error_MSE, Root_Mean_Squared_Log_Error_RMSLE, R2_score]
# Index: []

# %%
y8= df['Fare']
x8= df.drop(['Fare','Date_of_journey','Date_of_journey_new','Journey_Month'],axis=1)

# ----------------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(x8, y8, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 5122.9574234198
# MSE: 60095263.9257725
# RMSE: 7752.113513473117

# %%
# Build the Regression / Regressor models

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 5122.957
# Mean Squared Error (MSE): 60095263.926
# Root Mean Squared Error (RMSE): 7752.114
# R2_score: 0.854132
# Root Mean Squared Log Error (RMSLE): 8.956
# Mean Absolute Percentage Error (MAPE): 32.31 %
# Adj R Square:  0.854086
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 2538.788
# Mean Squared Error (MSE): 34260006.458
# Root Mean Squared Error (RMSE): 5853.205
# R2_score: 0.916842
# Root Mean Squared Log Error (RMSLE): 8.675
# Mean Absolute Percentage Error (MAPE): 11.66 %
# Adj R Square:  0.916816
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 2131.038
# Mean Squared Error (MSE): 18860414.6
# Root Mean Squared Error (RMSE): 4342.858
# R2_score: 0.954221
# Root Mean Squared Log Error (RMSLE): 8.376
# Mean Absolute Percentage Error (MAPE): 9.99 %
# Adj R Square:  0.954207
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 3257.954
# Mean Squared Error (MSE): 34424680.742
# Root Mean Squared Error (RMSE): 5867.255
# R2_score: 0.916442
# Root Mean Squared Log Error (RMSLE): 8.677
# Mean Absolute Percentage Error (MAPE): 16.6 %
# Adj R Square:  0.916416
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 2406.918
# Mean Squared Error (MSE): 26071689.732
# Root Mean Squared Error (RMSE): 5106.044
# R2_score: 0.936717
# Root Mean Squared Log Error (RMSLE): 8.538
# Mean Absolute Percentage Error (MAPE): 11.39 %
# Adj R Square:  0.936697
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 4000.346
# Mean Squared Error (MSE): 41979286.892
# Root Mean Squared Error (RMSE): 6479.142
# R2_score: 0.898105
# Root Mean Squared Log Error (RMSLE): 8.776
# Mean Absolute Percentage Error (MAPE): 21.78 %
# Adj R Square:  0.898073
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 3042.7
# Mean Squared Error (MSE): 26420377.483
# Root Mean Squared Error (RMSE): 5140.076
# R2_score: 0.93587
# Root Mean Squared Log Error (RMSLE): 8.545
# Mean Absolute Percentage Error (MAPE): 15.82 %
# Adj R Square:  0.93585
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 2221.92
# Mean Squared Error (MSE): 20732141.955
# Root Mean Squared Error (RMSE): 4553.256
# R2_score: 0.949677
# Root Mean Squared Log Error (RMSLE): 8.424
# Mean Absolute Percentage Error (MAPE): 10.44 %
# Adj R Square:  0.949661
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 5126.857
# Mean Squared Error (MSE): 60085789.766
# Root Mean Squared Error (RMSE): 7751.502
# R2_score: 0.854155
# Root Mean Squared Log Error (RMSLE): 8.956
# Mean Absolute Percentage Error (MAPE): 32.38 %
# Adj R Square:  0.854109
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 5126.706
# Mean Squared Error (MSE): 60086014.52
# Root Mean Squared Error (RMSE): 7751.517
# R2_score: 0.854155
# Root Mean Squared Log Error (RMSLE): 8.956
# Mean Absolute Percentage Error (MAPE): 32.38 %
# Adj R Square:  0.854109
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.337e+12, tolerance: 1.250e+10
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\3489303594.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %% [markdown]
#  # Making Controlled Inputs

# %% [markdown]
# # Observe the relationship by Considering The Classes:
# ## Considering the Economy Class

# %% [markdown]
# ## Checking the Individual Impact

# %%
df_Economy=df[df['Class_Economy']==1]

# %%
df_Economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252033 entries, 0 to 452017
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date_of_journey         252033 non-null  datetime64[ns]
#  1   Duration_in_hours       252033 non-null  float64
#  2   Days_left               252033 non-null  int64
#  3   Fare                    252033 non-null  int64
#  4   Journey_Month           252033 non-null  object
#  5   Journey_day_Friday      252033 non-null  uint8
#  6   Journey_day_Monday      252033 non-null  uint8
#  7   Journey_day_Saturday    252033 non-null  uint8
#  8   Journey_day_Sunday      252033 non-null  uint8
#  9   Journey_day_Thursday    252033 non-null  uint8
#  10  Journey_day_Tuesday     252033 non-null  uint8
#  11  Journey_day_Wednesday   252033 non-null  uint8
#  12  Airline_Air India       252033 non-null  uint8
#  13  Airline_AirAsia         252033 non-null  uint8
#  14  Airline_AkasaAir        252033 non-null  uint8
#  15  Airline_AllianceAir     252033 non-null  uint8
#  16  Airline_GO FIRST        252033 non-null  uint8
#  17  Airline_Indigo          252033 non-null  uint8
#  18  Airline_SpiceJet        252033 non-null  uint8
#  19  Airline_StarAir         252033 non-null  uint8
#  20  Airline_Vistara         252033 non-null  uint8
#  21  Class_Business          252033 non-null  uint8
#  22  Class_Economy           252033 non-null  uint8
#  23  Class_First             252033 non-null  uint8
#  24  Class_Premium Economy   252033 non-null  uint8
#  25  Source_Ahmedabad        252033 non-null  uint8
#  26  Source_Bangalore        252033 non-null  uint8
#  27  Source_Chennai          252033 non-null  uint8
#  28  Source_Delhi            252033 non-null  uint8
#  29  Source_Hyderabad        252033 non-null  uint8
#  30  Source_Kolkata          252033 non-null  uint8
#  31  Source_Mumbai           252033 non-null  uint8
#  32  Departure_12 PM - 6 PM  252033 non-null  uint8
#  33  Departure_6 AM - 12 PM  252033 non-null  uint8
#  34  Departure_After 6 PM    252033 non-null  uint8
#  35  Departure_Before 6 AM   252033 non-null  uint8
#  36  Total_stops_1-stop      252033 non-null  uint8
#  37  Total_stops_2+-stop     252033 non-null  uint8
#  38  Total_stops_non-stop    252033 non-null  uint8
#  39  Arrival_12 PM - 6 PM    252033 non-null  uint8
#  40  Arrival_6 AM - 12 PM    252033 non-null  uint8
#  41  Arrival_After 6 PM      252033 non-null  uint8
#  42  Arrival_Before 6 AM     252033 non-null  uint8
#  43  Destination_Ahmedabad   252033 non-null  uint8
#  44  Destination_Bangalore   252033 non-null  uint8
#  45  Destination_Chennai     252033 non-null  uint8
#  46  Destination_Delhi       252033 non-null  uint8
#  47  Destination_Hyderabad   252033 non-null  uint8
#  48  Destination_Kolkata     252033 non-null  uint8
#  49  Destination_Mumbai      252033 non-null  uint8
#  50  Date_of_journey_new     252033 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1), uint8(45)
# memory usage: 24.3+ MB

# %%
df_Economy.drop(['Class_Business','Class_First','Class_Premium Economy'],axis=1,inplace = True)
# Out:
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\645030306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Economy.drop(['Class_Business','Class_First','Class_Premium Economy'],axis=1,inplace = True)

# %%
df_Economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252033 entries, 0 to 452017
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date_of_journey         252033 non-null  datetime64[ns]
#  1   Duration_in_hours       252033 non-null  float64
#  2   Days_left               252033 non-null  int64
#  3   Fare                    252033 non-null  int64
#  4   Journey_Month           252033 non-null  object
#  5   Journey_day_Friday      252033 non-null  uint8
#  6   Journey_day_Monday      252033 non-null  uint8
#  7   Journey_day_Saturday    252033 non-null  uint8
#  8   Journey_day_Sunday      252033 non-null  uint8
#  9   Journey_day_Thursday    252033 non-null  uint8
#  10  Journey_day_Tuesday     252033 non-null  uint8
#  11  Journey_day_Wednesday   252033 non-null  uint8
#  12  Airline_Air India       252033 non-null  uint8
#  13  Airline_AirAsia         252033 non-null  uint8
#  14  Airline_AkasaAir        252033 non-null  uint8
#  15  Airline_AllianceAir     252033 non-null  uint8
#  16  Airline_GO FIRST        252033 non-null  uint8
#  17  Airline_Indigo          252033 non-null  uint8
#  18  Airline_SpiceJet        252033 non-null  uint8
#  19  Airline_StarAir         252033 non-null  uint8
#  20  Airline_Vistara         252033 non-null  uint8
#  21  Class_Economy           252033 non-null  uint8
#  22  Source_Ahmedabad        252033 non-null  uint8
#  23  Source_Bangalore        252033 non-null  uint8
#  24  Source_Chennai          252033 non-null  uint8
#  25  Source_Delhi            252033 non-null  uint8
#  26  Source_Hyderabad        252033 non-null  uint8
#  27  Source_Kolkata          252033 non-null  uint8
#  28  Source_Mumbai           252033 non-null  uint8
#  29  Departure_12 PM - 6 PM  252033 non-null  uint8
#  30  Departure_6 AM - 12 PM  252033 non-null  uint8
#  31  Departure_After 6 PM    252033 non-null  uint8
#  32  Departure_Before 6 AM   252033 non-null  uint8
#  33  Total_stops_1-stop      252033 non-null  uint8
#  34  Total_stops_2+-stop     252033 non-null  uint8
#  35  Total_stops_non-stop    252033 non-null  uint8
#  36  Arrival_12 PM - 6 PM    252033 non-null  uint8
#  37  Arrival_6 AM - 12 PM    252033 non-null  uint8
#  38  Arrival_After 6 PM      252033 non-null  uint8
#  39  Arrival_Before 6 AM     252033 non-null  uint8
#  40  Destination_Ahmedabad   252033 non-null  uint8
#  41  Destination_Bangalore   252033 non-null  uint8
#  42  Destination_Chennai     252033 non-null  uint8
#  43  Destination_Delhi       252033 non-null  uint8
#  44  Destination_Hyderabad   252033 non-null  uint8
#  45  Destination_Kolkata     252033 non-null  uint8
#  46  Destination_Mumbai      252033 non-null  uint8
#  47  Date_of_journey_new     252033 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1), uint8(42)
# memory usage: 23.6+ MB

# %%
import statsmodels.api as sm

# %% [markdown]
# # Individual testing of Independent Vars with Dependent Vars.

# %%
y9= df_Economy['Fare']
# x10= df.drop(['Fare','Date_of_journey','Date_of_journey_new','Journey_Month'],axis=1)
x9=df_Economy[['Duration_in_hours','Days_left','Journey_day_Friday',
                'Journey_day_Monday','Journey_day_Saturday','Journey_day_Sunday',
                'Journey_day_Thursday','Journey_day_Tuesday','Journey_day_Wednesday',
                'Airline_Air India','Airline_AirAsia','Airline_AkasaAir',
                'Airline_AllianceAir','Airline_GO FIRST',
                'Airline_Indigo','Airline_SpiceJet','Airline_StarAir','Airline_Vistara',
                'Class_Economy',
                'Source_Ahmedabad','Source_Bangalore','Source_Chennai','Source_Delhi',
                'Source_Hyderabad','Source_Kolkata','Source_Mumbai','Departure_12 PM - 6 PM',
                'Departure_6 AM - 12 PM','Departure_After 6 PM','Departure_Before 6 AM',
                'Total_stops_1-stop','Total_stops_2+-stop','Total_stops_non-stop',
                'Arrival_12 PM - 6 PM','Arrival_6 AM - 12 PM','Arrival_After 6 PM',
                'Arrival_Before 6 AM','Destination_Ahmedabad','Destination_Bangalore',
                'Destination_Chennai','Destination_Delhi','Destination_Hyderabad',
                'Destination_Kolkata','Destination_Mumbai']]
X=sm.add_constant(x9)
for i in X.columns:
    models = sm.OLS(y9,X[i])
    results = models.fit()
    print(f"Summary for {i}:\n{results.summary()}\n")
# Out:
# Summary for Duration_in_hours:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.699
# Model:                            OLS   Adj. R-squared (uncentered):              0.699
# Method:                 Least Squares   F-statistic:                          5.865e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:18   Log-Likelihood:                     -2.5557e+06
# No. Observations:              252033   AIC:                                  5.111e+06
# Df Residuals:                  252032   BIC:                                  5.111e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Duration_in_hours   706.9963      0.923    765.840      0.000     705.187     708.806
# ==============================================================================
# Omnibus:                     8749.444   Durbin-Watson:                   0.657
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25640.240
# Skew:                           0.028   Prob(JB):                         0.00
# Kurtosis:                       4.562   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Days_left:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.539
# Model:                            OLS   Adj. R-squared (uncentered):              0.539
# Method:                 Least Squares   F-statistic:                          2.941e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:18   Log-Likelihood:                     -2.6097e+06
# No. Observations:              252033   AIC:                                  5.219e+06
# Df Residuals:                  252032   BIC:                                  5.219e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Days_left    280.7778      0.518    542.321      0.000     279.763     281.793
# ==============================================================================
# Omnibus:                    21078.615   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28071.247
# Skew:                           0.720   Prob(JB):                         0.00
# Kurtosis:                       3.775   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Friday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                          3.421e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:18   Log-Likelihood:                     -2.6911e+06
# No. Observations:              252033   AIC:                                  5.382e+06
# Df Residuals:                  252032   BIC:                                  5.382e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Friday  1.028e+04     55.568    184.966      0.000    1.02e+04    1.04e+04
# ==============================================================================
# Omnibus:                     8453.159   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22600.200
# Skew:                           0.109   Prob(JB):                         0.00
# Kurtosis:                       4.451   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Monday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.130
# Model:                            OLS   Adj. R-squared (uncentered):              0.130
# Method:                 Least Squares   F-statistic:                          3.778e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:18   Log-Likelihood:                     -2.6895e+06
# No. Observations:              252033   AIC:                                  5.379e+06
# Df Residuals:                  252032   BIC:                                  5.379e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Monday  1.015e+04     52.202    194.370      0.000       1e+04    1.02e+04
# ==============================================================================
# Omnibus:                     6084.004   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14411.913
# Skew:                           0.038   Prob(JB):                         0.00
# Kurtosis:                       4.169   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Saturday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.117
# Model:                            OLS   Adj. R-squared (uncentered):              0.117
# Method:                 Least Squares   F-statistic:                          3.340e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:18   Log-Likelihood:                     -2.6915e+06
# No. Observations:              252033   AIC:                                  5.383e+06
# Df Residuals:                  252032   BIC:                                  5.383e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Journey_day_Saturday  1.035e+04     56.605    182.765      0.000    1.02e+04    1.05e+04
# ==============================================================================
# Omnibus:                     8588.958   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23624.403
# Skew:                           0.095   Prob(JB):                         0.00
# Kurtosis:                       4.488   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Sunday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.126
# Model:                            OLS   Adj. R-squared (uncentered):              0.126
# Method:                 Least Squares   F-statistic:                          3.620e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:18   Log-Likelihood:                     -2.6902e+06
# No. Observations:              252033   AIC:                                  5.380e+06
# Df Residuals:                  252032   BIC:                                  5.380e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Sunday  1.067e+04     56.063    190.264      0.000    1.06e+04    1.08e+04
# ==============================================================================
# Omnibus:                     8972.076   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25668.645
# Skew:                           0.086   Prob(JB):                         0.00
# Kurtosis:                       4.554   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Journey_day_Thursday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.115
# Model:                            OLS   Adj. R-squared (uncentered):              0.115
# Method:                 Least Squares   F-statistic:                          3.260e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.6918e+06
# No. Observations:              252033   AIC:                                  5.384e+06
# Df Residuals:                  252032   BIC:                                  5.384e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Journey_day_Thursday  9983.6419     55.290    180.567      0.000    9875.274    1.01e+04
# ==============================================================================
# Omnibus:                     8565.438   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22217.563
# Skew:                           0.134   Prob(JB):                         0.00
# Kurtosis:                       4.430   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Tuesday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.110
# Model:                            OLS   Adj. R-squared (uncentered):              0.110
# Method:                 Least Squares   F-statistic:                          3.113e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.6925e+06
# No. Observations:              252033   AIC:                                  5.385e+06
# Df Residuals:                  252032   BIC:                                  5.385e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Journey_day_Tuesday  9871.5743     55.947    176.444      0.000    9761.919    9981.230
# ==============================================================================
# Omnibus:                     7937.125   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20641.213
# Skew:                           0.099   Prob(JB):                         0.00
# Kurtosis:                       4.388   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Wednesday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.116
# Model:                            OLS   Adj. R-squared (uncentered):              0.116
# Method:                 Least Squares   F-statistic:                          3.317e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.6916e+06
# No. Observations:              252033   AIC:                                  5.383e+06
# Df Residuals:                  252032   BIC:                                  5.383e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Journey_day_Wednesday  1.018e+04     55.907    182.113      0.000    1.01e+04    1.03e+04
# ==============================================================================
# Omnibus:                     8730.042   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23849.095
# Skew:                           0.109   Prob(JB):                         0.00
# Kurtosis:                       4.491   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_Air India:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.273
# Model:                            OLS   Adj. R-squared (uncentered):              0.273
# Method:                 Least Squares   F-statistic:                          9.475e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.6669e+06
# No. Observations:              252033   AIC:                                  5.334e+06
# Df Residuals:                  252032   BIC:                                  5.334e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Airline_Air India   1.13e+04     36.719    307.819      0.000    1.12e+04    1.14e+04
# ==============================================================================
# Omnibus:                     4354.776   Durbin-Watson:                   0.231
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6320.494
# Skew:                           0.204   Prob(JB):                         0.00
# Kurtosis:                       3.660   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_AirAsia:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.025
# Model:                            OLS   Adj. R-squared (uncentered):              0.025
# Method:                 Least Squares   F-statistic:                              6502.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.7039e+06
# No. Observations:              252033   AIC:                                  5.408e+06
# Df Residuals:                  252032   BIC:                                  5.408e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_AirAsia  7092.2659     87.953     80.637      0.000    6919.881    7264.651
# ==============================================================================
# Omnibus:                    21615.415   Durbin-Watson:                   0.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55488.337
# Skew:                           0.504   Prob(JB):                         0.00
# Kurtosis:                       5.066   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_AkasaAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              227.4
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                    2.30e-51
# Time:                        18:36:19   Log-Likelihood:                     -2.7070e+06
# No. Observations:              252033   AIC:                                  5.414e+06
# Df Residuals:                  252032   BIC:                                  5.414e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_AkasaAir  3570.0345    236.737     15.080      0.000    3106.037    4034.032
# ==============================================================================
# Omnibus:                    49643.947   Durbin-Watson:                   0.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131206.743
# Skew:                           1.070   Prob(JB):                         0.00
# Kurtosis:                       5.813   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Airline_AllianceAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              52.24
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                    4.91e-13
# Time:                        18:36:19   Log-Likelihood:                     -2.7071e+06
# No. Observations:              252033   AIC:                                  5.414e+06
# Df Residuals:                  252032   BIC:                                  5.414e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Airline_AllianceAir  4077.5013    564.122      7.228      0.000    2971.838    5183.165
# ==============================================================================
# Omnibus:                    53388.978   Durbin-Watson:                   0.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           141344.926
# Skew:                           1.147   Prob(JB):                         0.00
# Kurtosis:                       5.864   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_GO FIRST:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.022
# Model:                            OLS   Adj. R-squared (uncentered):              0.022
# Method:                 Least Squares   F-statistic:                              5664.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.7043e+06
# No. Observations:              252033   AIC:                                  5.409e+06
# Df Residuals:                  252032   BIC:                                  5.409e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_GO FIRST  8015.0750    106.502     75.257      0.000    7806.334    8223.816
# ==============================================================================
# Omnibus:                    27166.330   Durbin-Watson:                   0.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            73369.274
# Skew:                           0.609   Prob(JB):                         0.00
# Kurtosis:                       5.346   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_Indigo:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.140
# Model:                            OLS   Adj. R-squared (uncentered):              0.140
# Method:                 Least Squares   F-statistic:                          4.103e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.6881e+06
# No. Observations:              252033   AIC:                                  5.376e+06
# Df Residuals:                  252032   BIC:                                  5.376e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Airline_Indigo  8198.7548     40.478    202.549      0.000    8119.419    8278.090
# ==============================================================================
# Omnibus:                     1509.094   Durbin-Watson:                   0.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1783.849
# Skew:                           0.130   Prob(JB):                         0.00
# Kurtosis:                       3.319   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_SpiceJet:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):              0.012
# Method:                 Least Squares   F-statistic:                              3121.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.7056e+06
# No. Observations:              252033   AIC:                                  5.411e+06
# Df Residuals:                  252032   BIC:                                  5.411e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_SpiceJet  8109.7732    145.172     55.863      0.000    7825.241    8394.306
# ==============================================================================
# Omnibus:                    38125.022   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            97967.526
# Skew:                           0.847   Prob(JB):                         0.00
# Kurtosis:                       5.541   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_StarAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              47.54
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                    5.40e-12
# Time:                        18:36:19   Log-Likelihood:                     -2.7071e+06
# No. Observations:              252033   AIC:                                  5.414e+06
# Df Residuals:                  252032   BIC:                                  5.414e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_StarAir  9792.7742   1420.291      6.895      0.000    7009.042    1.26e+04
# ==============================================================================
# Omnibus:                    53883.680   Durbin-Watson:                   0.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           143032.481
# Skew:                           1.156   Prob(JB):                         0.00
# Kurtosis:                       5.877   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_Vistara:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.391
# Model:                            OLS   Adj. R-squared (uncentered):              0.391
# Method:                 Least Squares   F-statistic:                          1.615e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:19   Log-Likelihood:                     -2.6447e+06
# No. Observations:              252033   AIC:                                  5.289e+06
# Df Residuals:                  252032   BIC:                                  5.289e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_Vistara  1.212e+04     30.154    401.859      0.000    1.21e+04    1.22e+04
# ==============================================================================
# Omnibus:                     1370.213   Durbin-Watson:                   0.321
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1894.970
# Skew:                           0.061   Prob(JB):                         0.00
# Kurtosis:                       3.407   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Class_Economy:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                nan
# Time:                        18:36:19   Log-Likelihood:            -2.4817e+06
# No. Observations:              252033   AIC:                         4.963e+06
# Df Residuals:                  252032   BIC:                         4.963e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Class_Economy  1.021e+04      9.109   1120.545      0.000    1.02e+04    1.02e+04
# ==============================================================================
# Omnibus:                    54309.913   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144155.955
# Skew:                           1.165   Prob(JB):                         0.00
# Kurtosis:                       5.881   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Ahmedabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.105
# Model:                            OLS   Adj. R-squared (uncentered):              0.105
# Method:                 Least Squares   F-statistic:                          2.948e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:20   Log-Likelihood:                     -2.6932e+06
# No. Observations:              252033   AIC:                                  5.386e+06
# Df Residuals:                  252032   BIC:                                  5.386e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Ahmedabad  1.149e+04     66.943    171.683      0.000    1.14e+04    1.16e+04
# ==============================================================================
# Omnibus:                    12226.658   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41626.312
# Skew:                          -0.135   Prob(JB):                         0.00
# Kurtosis:                       4.972   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Source_Bangalore:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.107
# Model:                            OLS   Adj. R-squared (uncentered):              0.107
# Method:                 Least Squares   F-statistic:                          3.030e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:20   Log-Likelihood:                     -2.6928e+06
# No. Observations:              252033   AIC:                                  5.386e+06
# Df Residuals:                  252032   BIC:                                  5.386e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Bangalore  9222.1467     52.976    174.080      0.000    9118.314    9325.979
# ==============================================================================
# Omnibus:                     6513.236   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15405.385
# Skew:                           0.081   Prob(JB):                         0.00
# Kurtosis:                       4.200   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Chennai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.101
# Model:                            OLS   Adj. R-squared (uncentered):              0.101
# Method:                 Least Squares   F-statistic:                          2.820e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:20   Log-Likelihood:                     -2.6938e+06
# No. Observations:              252033   AIC:                                  5.388e+06
# Df Residuals:                  252032   BIC:                                  5.388e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Source_Chennai  9988.7480     59.480    167.936      0.000    9872.170    1.01e+04
# ==============================================================================
# Omnibus:                    10846.714   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33500.886
# Skew:                           0.134   Prob(JB):                         0.00
# Kurtosis:                       4.766   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Delhi:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.138
# Model:                            OLS   Adj. R-squared (uncentered):              0.138
# Method:                 Least Squares   F-statistic:                          4.050e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:20   Log-Likelihood:                     -2.6884e+06
# No. Observations:              252033   AIC:                                  5.377e+06
# Df Residuals:                  252032   BIC:                                  5.377e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Source_Delhi  9583.4721     47.619    201.254      0.000    9490.141    9676.804
# ==============================================================================
# Omnibus:                     4868.735   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8083.338
# Skew:                           0.179   Prob(JB):                         0.00
# Kurtosis:                       3.801   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Hyderabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.098
# Model:                            OLS   Adj. R-squared (uncentered):              0.098
# Method:                 Least Squares   F-statistic:                          2.745e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:20   Log-Likelihood:                     -2.6941e+06
# No. Observations:              252033   AIC:                                  5.388e+06
# Df Residuals:                  252032   BIC:                                  5.388e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Hyderabad  9837.2071     59.378    165.671      0.000    9720.828    9953.587
# ==============================================================================
# Omnibus:                     9991.879   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25797.558
# Skew:                           0.195   Prob(JB):                         0.00
# Kurtosis:                       4.518   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# ...
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.053
# Model:                            OLS   Adj. R-squared (uncentered):              0.053
# Method:                 Least Squares   F-statistic:                          1.401e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.7003e+06
# No. Observations:              252033   AIC:                                  5.401e+06
# Df Residuals:                  252032   BIC:                                  5.401e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Arrival_Before 6 AM  8748.9981     73.919    118.359      0.000    8604.118    8893.878
# ==============================================================================
# Omnibus:                    15249.461   Durbin-Watson:                   0.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            40296.177
# Skew:                           0.344   Prob(JB):                         0.00
# Kurtosis:                       4.834   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Ahmedabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.073
# Model:                            OLS   Adj. R-squared (uncentered):              0.073
# Method:                 Least Squares   F-statistic:                          1.996e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6975e+06
# No. Observations:              252033   AIC:                                  5.395e+06
# Df Residuals:                  252032   BIC:                                  5.395e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Ahmedabad  9889.1246     69.998    141.278      0.000    9751.931       1e+04
# ==============================================================================
# Omnibus:                    12013.349   Durbin-Watson:                   0.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35977.525
# Skew:                           0.200   Prob(JB):                         0.00
# Kurtosis:                       4.807   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Bangalore:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.112
# Model:                            OLS   Adj. R-squared (uncentered):              0.112
# Method:                 Least Squares   F-statistic:                          3.182e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6922e+06
# No. Observations:              252033   AIC:                                  5.384e+06
# Df Residuals:                  252032   BIC:                                  5.384e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Bangalore  9347.6218     52.404    178.376      0.000    9244.911    9450.332
# ==============================================================================
# Omnibus:                     6244.728   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14955.646
# Skew:                           0.042   Prob(JB):                         0.00
# Kurtosis:                       4.190   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Chennai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.112
# Model:                            OLS   Adj. R-squared (uncentered):              0.112
# Method:                 Least Squares   F-statistic:                          3.165e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6922e+06
# No. Observations:              252033   AIC:                                  5.384e+06
# Df Residuals:                  252032   BIC:                                  5.384e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Destination_Chennai  1.047e+04     58.876    177.902      0.000    1.04e+04    1.06e+04
# ==============================================================================
# Omnibus:                     9791.620   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30803.785
# Skew:                           0.039   Prob(JB):                         0.00
# Kurtosis:                       4.711   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Delhi:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.141
# Model:                            OLS   Adj. R-squared (uncentered):              0.141
# Method:                 Least Squares   F-statistic:                          4.126e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6880e+06
# No. Observations:              252033   AIC:                                  5.376e+06
# Df Residuals:                  252032   BIC:                                  5.376e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Destination_Delhi  9945.6854     48.961    203.134      0.000    9849.723       1e+04
# ==============================================================================
# Omnibus:                     5346.633   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9964.469
# Skew:                           0.155   Prob(JB):                         0.00
# Kurtosis:                       3.924   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Hyderabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.104
# Model:                            OLS   Adj. R-squared (uncentered):              0.104
# Method:                 Least Squares   F-statistic:                          2.920e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6933e+06
# No. Observations:              252033   AIC:                                  5.387e+06
# Df Residuals:                  252032   BIC:                                  5.387e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Hyderabad  9717.2008     56.862    170.890      0.000    9605.752    9828.649
# ==============================================================================
# Omnibus:                     8290.431   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20442.815
# Skew:                           0.150   Prob(JB):                         0.00
# Kurtosis:                       4.363   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Kolkata:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.145
# Model:                            OLS   Adj. R-squared (uncentered):              0.145
# Method:                 Least Squares   F-statistic:                          4.290e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6873e+06
# No. Observations:              252033   AIC:                                  5.375e+06
# Df Residuals:                  252032   BIC:                                  5.375e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Destination_Kolkata  1.185e+04     57.212    207.116      0.000    1.17e+04     1.2e+04
# ==============================================================================
# Omnibus:                    11449.039   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29618.388
# Skew:                           0.244   Prob(JB):                         0.00
# Kurtosis:                       4.607   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Mumbai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.150
# Model:                            OLS   Adj. R-squared (uncentered):              0.150
# Method:                 Least Squares   F-statistic:                          4.452e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:36:21   Log-Likelihood:                     -2.6866e+06
# No. Observations:              252033   AIC:                                  5.373e+06
# Df Residuals:                  252032   BIC:                                  5.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  1.041e+04     49.323    210.991      0.000    1.03e+04    1.05e+04
# ==============================================================================
# Omnibus:                     7416.882   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19754.440
# Skew:                          -0.005   Prob(JB):                         0.00
# Kurtosis:                       4.372   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Combine Model Run

# %%
y9= df_Economy['Fare']
x9=df_Economy.drop(['Fare','Date_of_journey','Date_of_journey_new','Journey_Month'],axis=1)
X=sm.add_constant(x9)
models = sm.OLS(y9,X)
result=models.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     6168.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:36:22   Log-Likelihood:            -2.4021e+06
# No. Observations:              252033   AIC:                         4.804e+06
# Df Residuals:                  251996   BIC:                         4.805e+06
# Df Model:                          36
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Duration_in_hours        -11.4707      1.286     -8.918      0.000     -13.992      -8.950
# Days_left               -100.7165      0.467   -215.888      0.000    -101.631     -99.802
# Journey_day_Friday       795.2713     16.705     47.608      0.000     762.531     828.012
# Journey_day_Monday       624.8930     15.949     39.182      0.000     593.634     656.152
# Journey_day_Saturday    1024.6808     16.945     60.469      0.000     991.468    1057.893
# Journey_day_Sunday      1412.3452     16.964     83.256      0.000    1379.097    1445.594
# Journey_day_Thursday     411.3194     16.542     24.865      0.000     378.898     443.741
# Journey_day_Tuesday      119.6170     16.665      7.178      0.000      86.954     152.280
# Journey_day_Wednesday    506.4764     16.728     30.277      0.000     473.690     539.262
# Airline_Air India       2346.5757     51.474     45.587      0.000    2245.687    2447.464
# Airline_AirAsia        -1638.4143     55.128    -29.720      0.000   -1746.464   -1530.365
# Airline_AkasaAir       -1132.9578     81.165    -13.959      0.000   -1292.038    -973.877
# Airline_AllianceAir    -1388.1165    157.704     -8.802      0.000   -1697.212   -1079.021
# Airline_GO FIRST        -239.5219     57.458     -4.169      0.000    -352.138    -126.906
# Airline_Indigo          -144.5918     51.003     -2.835      0.005    -244.557     -44.626
# Airline_SpiceJet        -187.7286     63.306     -2.965      0.003    -311.807     -63.651
# Airline_StarAir         4279.3487    379.499     11.276      0.000    3535.541    5023.157
# Airline_Vistara         3000.0096     51.014     58.808      0.000    2900.024    3099.995
# Class_Economy           4894.6031     23.423    208.967      0.000    4848.695    4940.511
# Source_Ahmedabad        1676.2162     20.008     83.777      0.000    1637.001    1715.432
# Source_Bangalore        -359.2287     16.370    -21.945      0.000    -391.313    -327.145
# Source_Chennai           165.4884     18.024      9.182      0.000     130.162     200.815
# Source_Delhi             315.2359     15.502     20.335      0.000     284.852     345.620
# Source_Hyderabad          -3.6403     17.834     -0.204      0.838     -38.595      31.314
# Source_Kolkata          2819.7099     17.632    159.921      0.000    2785.152    2854.268
# Source_Mumbai            280.8217     16.008     17.542      0.000     249.446     312.198
# Departure_12 PM - 6 PM  1268.7828     13.656     92.911      0.000    1242.018    1295.548
# Departure_6 AM - 12 PM  1339.1784     12.788    104.723      0.000    1314.115    1364.242
# Departure_After 6 PM    1170.3831     14.090     83.065      0.000    1142.767    1197.999
# Departure_Before 6 AM   1116.2588     22.119     50.467      0.000    1072.907    1159.611
# Total_stops_1-stop      2362.7539     13.405    176.264      0.000    2336.481    2389.027
# Total_stops_2+-stop     4016.6234     22.381    179.467      0.000    3972.757    4060.489
# Total_stops_non-stop   -1484.7742     18.301    -81.131      0.000   -1520.644   -1448.905
# Arrival_12 PM - 6 PM    1591.0094     14.319    111.109      0.000    1562.944    1619.075
# Arrival_6 AM - 12 PM     732.2922     13.863     52.822      0.000     705.120     759.464
# Arrival_After 6 PM      1672.9177     12.211    137.003      0.000    1648.985    1696.851
# Arrival_Before 6 AM      898.3839     20.072     44.757      0.000     859.043     937.725
# Destination_Ahmedabad    -44.7664     20.244     -2.211      0.027     -84.443      -5.090
# Destination_Bangalore   -112.7436     16.353     -6.894      0.000    -144.796     -80.691
# Destination_Chennai      876.2747     17.853     49.082      0.000     841.283     911.267
# Destination_Delhi        646.2211     15.897     40.649      0.000     615.062     677.380
# Destination_Hyderabad    101.9482     17.284      5.899      0.000      68.073     135.824
# Destination_Kolkata     2557.2339     17.763    143.965      0.000    2522.419    2592.049
# Destination_Mumbai       870.4353     15.855     54.899      0.000     839.360     901.511
# ==============================================================================
# Omnibus:                    85404.262   Durbin-Watson:                   0.417
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           442571.810
# Skew:                           1.557   Prob(JB):                         0.00
# Kurtosis:                       8.696   Cond. No.                     1.46e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.13e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
#  RUnning Classification Models

# %%
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x9, y9, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 2418.344615310625
# MSE: 11082742.358995322
# RMSE: 3329.0753008899214
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 2418.345
# Mean Squared Error (MSE): 11082742.359
# Root Mean Squared Error (RMSE): 3329.075
# R2_score: 0.469573
# Root Mean Squared Log Error (RMSLE): 8.11
# Mean Absolute Percentage Error (MAPE): 27.54 %
# Adj R Square:  0.469292
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 1640.755
# Mean Squared Error (MSE): 9398626.181
# Root Mean Squared Error (RMSE): 3065.718
# R2_score: 0.550176
# Root Mean Squared Log Error (RMSLE): 8.028
# Mean Absolute Percentage Error (MAPE): 16.21 %
# Adj R Square:  0.549938
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 1343.378
# Mean Squared Error (MSE): 5383535.307
# Root Mean Squared Error (RMSE): 2320.245
# R2_score: 0.742341
# Root Mean Squared Log Error (RMSLE): 7.749
# Mean Absolute Percentage Error (MAPE): 13.55 %
# Adj R Square:  0.742205
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 1699.486
# Mean Squared Error (MSE): 7280112.294
# Root Mean Squared Error (RMSE): 2698.168
# R2_score: 0.651569
# Root Mean Squared Log Error (RMSLE): 7.9
# Mean Absolute Percentage Error (MAPE): 17.34 %
# Adj R Square:  0.651385
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 1387.39
# Mean Squared Error (MSE): 6313455.107
# Root Mean Squared Error (RMSE): 2512.659
# R2_score: 0.697834
# Root Mean Squared Log Error (RMSLE): 7.829
# Mean Absolute Percentage Error (MAPE): 13.79 %
# Adj R Square:  0.697674
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 2082.087
# Mean Squared Error (MSE): 8719951.77
# Root Mean Squared Error (RMSE): 2952.956
# R2_score: 0.582658
# Root Mean Squared Log Error (RMSLE): 7.991
# Mean Absolute Percentage Error (MAPE): 22.66 %
# Adj R Square:  0.582437
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 1670.444
# Mean Squared Error (MSE): 6177706.516
# Root Mean Squared Error (RMSE): 2485.499
# R2_score: 0.704331
# Root Mean Squared Log Error (RMSLE): 7.818
# Mean Absolute Percentage Error (MAPE): 17.43 %
# Adj R Square:  0.704174
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 1405.341
# Mean Squared Error (MSE): 5850644.773
# Root Mean Squared Error (RMSE): 2418.811
# R2_score: 0.719985
# Root Mean Squared Log Error (RMSLE): 7.791
# Mean Absolute Percentage Error (MAPE): 14.16 %
# Adj R Square:  0.719837
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 2418.09
# Mean Squared Error (MSE): 11082543.874
# Root Mean Squared Error (RMSE): 3329.045
# R2_score: 0.469583
# Root Mean Squared Log Error (RMSLE): 8.11
# Mean Absolute Percentage Error (MAPE): 27.54 %
# Adj R Square:  0.469302
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 2417.909
# Mean Squared Error (MSE): 11082397.838
# Root Mean Squared Error (RMSE): 3329.024
# R2_score: 0.46959
# Root Mean Squared Log Error (RMSLE): 8.11
# Mean Absolute Percentage Error (MAPE): 27.53 %
# Adj R Square:  0.469309
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.535e+11, tolerance: 3.533e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\483530651.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %% [markdown]
# # Class Economy and Flight: Indigo

# %%
df_Economy_Indigo=df_Economy[df_Economy['Airline_Indigo']==1]

# %%
df_Economy_Indigo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65659 entries, 1 to 452017
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date_of_journey         65659 non-null  datetime64[ns]
#  1   Duration_in_hours       65659 non-null  float64
#  2   Days_left               65659 non-null  int64
#  3   Fare                    65659 non-null  int64
#  4   Journey_Month           65659 non-null  object
#  5   Journey_day_Friday      65659 non-null  uint8
#  6   Journey_day_Monday      65659 non-null  uint8
#  7   Journey_day_Saturday    65659 non-null  uint8
#  8   Journey_day_Sunday      65659 non-null  uint8
#  9   Journey_day_Thursday    65659 non-null  uint8
#  10  Journey_day_Tuesday     65659 non-null  uint8
#  11  Journey_day_Wednesday   65659 non-null  uint8
#  12  Airline_Air India       65659 non-null  uint8
#  13  Airline_AirAsia         65659 non-null  uint8
#  14  Airline_AkasaAir        65659 non-null  uint8
#  15  Airline_AllianceAir     65659 non-null  uint8
#  16  Airline_GO FIRST        65659 non-null  uint8
#  17  Airline_Indigo          65659 non-null  uint8
#  18  Airline_SpiceJet        65659 non-null  uint8
#  19  Airline_StarAir         65659 non-null  uint8
#  20  Airline_Vistara         65659 non-null  uint8
#  21  Class_Economy           65659 non-null  uint8
#  22  Source_Ahmedabad        65659 non-null  uint8
#  23  Source_Bangalore        65659 non-null  uint8
#  24  Source_Chennai          65659 non-null  uint8
#  25  Source_Delhi            65659 non-null  uint8
#  26  Source_Hyderabad        65659 non-null  uint8
#  27  Source_Kolkata          65659 non-null  uint8
#  28  Source_Mumbai           65659 non-null  uint8
#  29  Departure_12 PM - 6 PM  65659 non-null  uint8
#  30  Departure_6 AM - 12 PM  65659 non-null  uint8
#  31  Departure_After 6 PM    65659 non-null  uint8
#  32  Departure_Before 6 AM   65659 non-null  uint8
#  33  Total_stops_1-stop      65659 non-null  uint8
#  34  Total_stops_2+-stop     65659 non-null  uint8
#  35  Total_stops_non-stop    65659 non-null  uint8
#  36  Arrival_12 PM - 6 PM    65659 non-null  uint8
#  37  Arrival_6 AM - 12 PM    65659 non-null  uint8
#  38  Arrival_After 6 PM      65659 non-null  uint8
#  39  Arrival_Before 6 AM     65659 non-null  uint8
#  40  Destination_Ahmedabad   65659 non-null  uint8
#  41  Destination_Bangalore   65659 non-null  uint8
#  42  Destination_Chennai     65659 non-null  uint8
#  43  Destination_Delhi       65659 non-null  uint8
#  44  Destination_Hyderabad   65659 non-null  uint8
#  45  Destination_Kolkata     65659 non-null  uint8
#  46  Destination_Mumbai      65659 non-null  uint8
#  47  Date_of_journey_new     65659 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1), uint8(42)
# memory usage: 6.1+ MB

# %%
y10=df_Economy_Indigo['Fare']
x10 = df_Economy_Indigo.drop(['Date_of_journey_new','Fare','Journey_Month','Date_of_journey'],axis=1)
# x10 = df_Economy_Indigo.drop('Date_of_journey',axis=1)
# x10 = df_Economy_Indigo.drop('Journey_Month',axis=1)

# %%
x10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65659 entries, 1 to 452017
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Duration_in_hours       65659 non-null  float64
#  1   Days_left               65659 non-null  int64
#  2   Journey_day_Friday      65659 non-null  uint8
#  3   Journey_day_Monday      65659 non-null  uint8
#  4   Journey_day_Saturday    65659 non-null  uint8
#  5   Journey_day_Sunday      65659 non-null  uint8
#  6   Journey_day_Thursday    65659 non-null  uint8
#  7   Journey_day_Tuesday     65659 non-null  uint8
#  8   Journey_day_Wednesday   65659 non-null  uint8
#  9   Airline_Air India       65659 non-null  uint8
#  10  Airline_AirAsia         65659 non-null  uint8
#  11  Airline_AkasaAir        65659 non-null  uint8
#  12  Airline_AllianceAir     65659 non-null  uint8
#  13  Airline_GO FIRST        65659 non-null  uint8
#  14  Airline_Indigo          65659 non-null  uint8
#  15  Airline_SpiceJet        65659 non-null  uint8
#  16  Airline_StarAir         65659 non-null  uint8
#  17  Airline_Vistara         65659 non-null  uint8
#  18  Class_Economy           65659 non-null  uint8
#  19  Source_Ahmedabad        65659 non-null  uint8
#  20  Source_Bangalore        65659 non-null  uint8
#  21  Source_Chennai          65659 non-null  uint8
#  22  Source_Delhi            65659 non-null  uint8
#  23  Source_Hyderabad        65659 non-null  uint8
#  24  Source_Kolkata          65659 non-null  uint8
#  25  Source_Mumbai           65659 non-null  uint8
#  26  Departure_12 PM - 6 PM  65659 non-null  uint8
#  27  Departure_6 AM - 12 PM  65659 non-null  uint8
#  28  Departure_After 6 PM    65659 non-null  uint8
#  29  Departure_Before 6 AM   65659 non-null  uint8
#  30  Total_stops_1-stop      65659 non-null  uint8
#  31  Total_stops_2+-stop     65659 non-null  uint8
#  32  Total_stops_non-stop    65659 non-null  uint8
#  33  Arrival_12 PM - 6 PM    65659 non-null  uint8
#  34  Arrival_6 AM - 12 PM    65659 non-null  uint8
#  35  Arrival_After 6 PM      65659 non-null  uint8
#  36  Arrival_Before 6 AM     65659 non-null  uint8
#  37  Destination_Ahmedabad   65659 non-null  uint8
#  38  Destination_Bangalore   65659 non-null  uint8
#  39  Destination_Chennai     65659 non-null  uint8
#  40  Destination_Delhi       65659 non-null  uint8
#  41  Destination_Hyderabad   65659 non-null  uint8
#  42  Destination_Kolkata     65659 non-null  uint8
#  43  Destination_Mumbai      65659 non-null  uint8
# dtypes: float64(1), int64(1), uint8(42)
# memory usage: 4.1 MB

# %%
X= sm.add_constant(x10)
for i in X.columns:
    models= sm.OLS(y10,X[i])
    results= models.fit()
    print(f"Summary for {i}:\n{results.summary()}\n")
# Out:
# Summary for Duration_in_hours:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.816
# Model:                            OLS   Adj. R-squared (uncentered):              0.816
# Method:                 Least Squares   F-statistic:                          2.921e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.3493e+05
# No. Observations:               65659   AIC:                                  1.270e+06
# Df Residuals:                   65658   BIC:                                  1.270e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Duration_in_hours  1420.0329      2.627    540.505      0.000    1414.884    1425.182
# ==============================================================================
# Omnibus:                     6045.218   Durbin-Watson:                   0.682
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16176.334
# Skew:                           0.526   Prob(JB):                         0.00
# Kurtosis:                       5.192   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Days_left:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.544
# Model:                            OLS   Adj. R-squared (uncentered):              0.544
# Method:                 Least Squares   F-statistic:                          7.830e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.6482e+05
# No. Observations:               65659   AIC:                                  1.330e+06
# Df Residuals:                   65658   BIC:                                  1.330e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Days_left    225.4467      0.806    279.827      0.000     223.868     227.026
# ==============================================================================
# Omnibus:                     5772.665   Durbin-Watson:                   0.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7624.296
# Skew:                           0.757   Prob(JB):                         0.00
# Kurtosis:                       3.705   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Friday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8979.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8639e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Friday  8242.6654     86.987     94.757      0.000    8072.170    8413.161
# ==============================================================================
# Omnibus:                     3277.989   Durbin-Watson:                   0.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9962.794
# Skew:                           0.212   Prob(JB):                         0.00
# Kurtosis:                       4.861   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Monday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.135
# Model:                            OLS   Adj. R-squared (uncentered):              0.135
# Method:                 Least Squares   F-statistic:                          1.021e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8585e+05
# No. Observations:               65659   AIC:                                  1.372e+06
# Df Residuals:                   65658   BIC:                                  1.372e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Monday  8203.1441     81.164    101.069      0.000    8044.062    8362.226
# ==============================================================================
# Omnibus:                     2499.291   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7231.291
# Skew:                           0.114   Prob(JB):                         0.00
# Kurtosis:                       4.610   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Saturday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.118
# Model:                            OLS   Adj. R-squared (uncentered):              0.118
# Method:                 Least Squares   F-statistic:                              8804.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8647e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Journey_day_Saturday  8274.4821     88.186     93.830      0.000    8101.637    8447.327
# ==============================================================================
# Omnibus:                     3000.263   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9089.860
# Skew:                           0.174   Prob(JB):                         0.00
# Kurtosis:                       4.789   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Sunday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.133
# Model:                            OLS   Adj. R-squared (uncentered):              0.133
# Method:                 Least Squares   F-statistic:                          1.003e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8593e+05
# No. Observations:               65659   AIC:                                  1.372e+06
# Df Residuals:                   65658   BIC:                                  1.372e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Sunday  8764.0141     87.508    100.152      0.000    8592.499    8935.529
# ==============================================================================
# Omnibus:                     2900.904   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9904.376
# Skew:                           0.059   Prob(JB):                         0.00
# Kurtosis:                       4.899   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Thursday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.115
# Model:                            OLS   Adj. R-squared (uncentered):              0.115
# Method:                 Least Squares   F-statistic:                              8500.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8660e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Journey_day_Thursday  7984.6030     86.605     92.196      0.000    7814.857    8154.349
# ==============================================================================
# Omnibus:                     3195.506   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9434.227
# Skew:                           0.214   Prob(JB):                         0.00
# Kurtosis:                       4.807   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Tuesday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.103
# Model:                            OLS   Adj. R-squared (uncentered):              0.103
# Method:                 Least Squares   F-statistic:                              7527.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8703e+05
# No. Observations:               65659   AIC:                                  1.374e+06
# Df Residuals:                   65658   BIC:                                  1.374e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Journey_day_Tuesday  7693.0652     88.674     86.756      0.000    7519.263    7866.867
# ==============================================================================
# Omnibus:                     3123.842   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9083.518
# Skew:                           0.212   Prob(JB):                         0.00
# Kurtosis:                       4.772   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Wednesday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.118
# Model:                            OLS   Adj. R-squared (uncentered):              0.118
# Method:                 Least Squares   F-statistic:                              8767.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:12   Log-Likelihood:                     -6.8648e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Journey_day_Wednesday  8239.7831     88.000     93.634      0.000    8067.304    8412.263
# ==============================================================================
# Omnibus:                     3257.982   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10443.743
# Skew:                           0.183   Prob(JB):                         0.00
# Kurtosis:                       4.919   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Airline_Air India:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:12   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Airline_Air India          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Airline_AirAsia:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:12   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_AirAsia          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Airline_AkasaAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:12   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_AkasaAir          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Airline_AllianceAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:12   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Airline_AllianceAir          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary for Airline_GO FIRST:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:12   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_GO FIRST          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\abhi9\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# Summary for Airline_Indigo:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                nan
# Time:                        18:48:13   Log-Likelihood:            -6.3046e+05
# No. Observations:               65659   AIC:                         1.261e+06
# Df Residuals:                   65658   BIC:                         1.261e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Airline_Indigo  8198.7548     13.972    586.810      0.000    8171.370    8226.139
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_SpiceJet:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:13   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_SpiceJet          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Airline_StarAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:13   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_StarAir          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Airline_Vistara:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                                nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                         nan
# Time:                        18:48:13   Log-Likelihood:                     -6.9060e+05
# No. Observations:               65659   AIC:                                  1.381e+06
# Df Residuals:                   65659   BIC:                                  1.381e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_Vistara          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                          nan
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Summary for Class_Economy:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                nan
# Time:                        18:48:13   Log-Likelihood:            -6.3046e+05
# No. Observations:               65659   AIC:                         1.261e+06
# Df Residuals:                   65658   BIC:                         1.261e+06
# Df Model:                           0
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Class_Economy  8198.7548     13.972    586.810      0.000    8171.370    8226.139
# ==============================================================================
# Omnibus:                    18439.163   Durbin-Watson:                   0.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64620.918
# Skew:                           1.398   Prob(JB):                         0.00
# Kurtosis:                       6.975   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Ahmedabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.088
# Model:                            OLS   Adj. R-squared (uncentered):              0.088
# Method:                 Least Squares   F-statistic:                              6356.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8756e+05
# No. Observations:               65659   AIC:                                  1.375e+06
# Df Residuals:                   65658   BIC:                                  1.375e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Ahmedabad  8050.2991    100.976     79.725      0.000    7852.387    8248.212
# ==============================================================================
# Omnibus:                     3580.043   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12529.665
# Skew:                           0.183   Prob(JB):                         0.00
# Kurtosis:                       5.108   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Bangalore:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.088
# Model:                            OLS   Adj. R-squared (uncentered):              0.088
# Method:                 Least Squares   F-statistic:                              6327.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8758e+05
# No. Observations:               65659   AIC:                                  1.375e+06
# Df Residuals:                   65658   BIC:                                  1.375e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Bangalore  6974.2831     87.680     79.543      0.000    6802.430    7146.136
# ==============================================================================
# Omnibus:                     2938.006   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8141.875
# Skew:                           0.209   Prob(JB):                         0.00
# Kurtosis:                       4.674   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Chennai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.095
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              6923.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8731e+05
# No. Observations:               65659   AIC:                                  1.375e+06
# Df Residuals:                   65658   BIC:                                  1.375e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Source_Chennai  7448.9485     89.524     83.206      0.000    7273.482    7624.415
# ==============================================================================
# Omnibus:                     2963.194   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8746.782
# Skew:                           0.182   Prob(JB):                         0.00
# Kurtosis:                       4.751   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Delhi:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.153
# Model:                            OLS   Adj. R-squared (uncentered):              0.153
# Method:                 Least Squares   F-statistic:                          1.189e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8513e+05
# No. Observations:               65659   AIC:                                  1.370e+06
# Df Residuals:                   65658   BIC:                                  1.370e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Source_Delhi  8531.7411     78.240    109.046      0.000    8378.390    8685.092
# ==============================================================================
# Omnibus:                     2625.485   Durbin-Watson:                   0.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6407.064
# Skew:                           0.222   Prob(JB):                         0.00
# ...
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.130
# Model:                            OLS   Adj. R-squared (uncentered):              0.130
# Method:                 Least Squares   F-statistic:                              9829.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8602e+05
# No. Observations:               65659   AIC:                                  1.372e+06
# Df Residuals:                   65658   BIC:                                  1.372e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Arrival_Before 6 AM  7904.5728     79.731     99.140      0.000    7748.299    8060.846
# ==============================================================================
# Omnibus:                     2732.901   Durbin-Watson:                   0.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7339.869
# Skew:                           0.195   Prob(JB):                         0.00
# Kurtosis:                       4.591   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Ahmedabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.065
# Model:                            OLS   Adj. R-squared (uncentered):              0.065
# Method:                 Least Squares   F-statistic:                              4573.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8839e+05
# No. Observations:               65659   AIC:                                  1.377e+06
# Df Residuals:                   65658   BIC:                                  1.377e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Ahmedabad  7648.4142    113.096     67.628      0.000    7426.746    7870.083
# ==============================================================================
# Omnibus:                     5347.342   Durbin-Watson:                   0.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19808.621
# Skew:                           0.361   Prob(JB):                         0.00
# Kurtosis:                       5.592   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Bangalore:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.097
# Model:                            OLS   Adj. R-squared (uncentered):              0.097
# Method:                 Least Squares   F-statistic:                              7067.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8724e+05
# No. Observations:               65659   AIC:                                  1.374e+06
# Df Residuals:                   65658   BIC:                                  1.374e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Bangalore  7143.9014     84.981     84.065      0.000    6977.339    7310.463
# ==============================================================================
# Omnibus:                     2723.006   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7296.655
# Skew:                           0.195   Prob(JB):                         0.00
# Kurtosis:                       4.586   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Chennai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.113
# Model:                            OLS   Adj. R-squared (uncentered):              0.113
# Method:                 Least Squares   F-statistic:                              8364.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8666e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Destination_Chennai  8157.0496     89.193     91.454      0.000    7982.231    8331.868
# ==============================================================================
# Omnibus:                     2976.944   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10135.020
# Skew:                           0.087   Prob(JB):                         0.00
# Kurtosis:                       4.917   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Delhi:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.154
# Model:                            OLS   Adj. R-squared (uncentered):              0.154
# Method:                 Least Squares   F-statistic:                          1.195e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8511e+05
# No. Observations:               65659   AIC:                                  1.370e+06
# Df Residuals:                   65658   BIC:                                  1.370e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Destination_Delhi  8692.5901     79.526    109.304      0.000    8536.718    8848.462
# ==============================================================================
# Omnibus:                     2818.131   Durbin-Watson:                   0.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7526.077
# Skew:                           0.209   Prob(JB):                         0.00
# Kurtosis:                       4.605   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Hyderabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.121
# Model:                            OLS   Adj. R-squared (uncentered):              0.121
# Method:                 Least Squares   F-statistic:                              9066.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8635e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Hyderabad  7798.8875     81.906     95.217      0.000    7638.351    7959.424
# ==============================================================================
# Omnibus:                     2607.838   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6857.175
# Skew:                           0.187   Prob(JB):                         0.00
# Kurtosis:                       4.538   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Destination_Kolkata:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.178
# Model:                            OLS   Adj. R-squared (uncentered):              0.178
# Method:                 Least Squares   F-statistic:                          1.422e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8416e+05
# No. Observations:               65659   AIC:                                  1.368e+06
# Df Residuals:                   65658   BIC:                                  1.368e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Destination_Kolkata  9825.7614     82.398    119.248      0.000    9664.262    9987.261
# ==============================================================================
# Omnibus:                     3004.048   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8496.601
# Skew:                           0.208   Prob(JB):                         0.00
# Kurtosis:                       4.712   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Mumbai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:13   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
models=sm.OLS(y10,X)
result=models.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     1691.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:48:13   Log-Likelihood:            -6.1263e+05
# No. Observations:               65659   AIC:                         1.225e+06
# Df Residuals:                   65630   BIC:                         1.226e+06
# Df Model:                          28
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Duration_in_hours        -19.2331     10.209     -1.884      0.060     -39.243       0.777
# Days_left                -75.3271      0.742   -101.487      0.000     -76.782     -73.872
# Journey_day_Friday       517.7587     26.403     19.610      0.000     466.008     569.509
# Journey_day_Monday       430.1084     25.108     17.131      0.000     380.897     479.319
# Journey_day_Saturday     664.1176     26.776     24.803      0.000     611.637     716.598
# Journey_day_Sunday      1240.5085     26.840     46.219      0.000    1187.903    1293.114
# Journey_day_Thursday     218.0018     26.277      8.296      0.000     166.500     269.504
# Journey_day_Tuesday     -175.3942     26.630     -6.586      0.000    -227.589    -123.200
# Journey_day_Wednesday    360.0922     26.624     13.525      0.000     307.909     412.276
# Airline_Air India       1.356e-12   2.51e-14     54.053      0.000    1.31e-12    1.41e-12
# Airline_AirAsia        -1.054e-12   3.32e-14    -31.767      0.000   -1.12e-12   -9.89e-13
# Airline_AkasaAir       -4.161e-13   4.42e-14     -9.404      0.000   -5.03e-13   -3.29e-13
# Airline_AllianceAir     6.805e-13   3.71e-14     18.334      0.000    6.08e-13    7.53e-13
# Airline_GO FIRST         1.02e-12   2.04e-14     49.917      0.000     9.8e-13    1.06e-12
# Airline_Indigo          3255.1929     24.494    132.900      0.000    3207.186    3303.200
# Airline_SpiceJet        5.992e-13   1.75e-14     34.185      0.000    5.65e-13    6.34e-13
# Airline_StarAir        -9.809e-14   1.27e-14     -7.744      0.000   -1.23e-13   -7.33e-14
# Airline_Vistara         6.357e-13   1.33e-14     47.865      0.000     6.1e-13    6.62e-13
# Class_Economy           3255.1929     24.494    132.900      0.000    3207.186    3303.200
# Source_Ahmedabad         253.4653     30.598      8.284      0.000     193.494     313.437
# Source_Bangalore        -894.6997     27.125    -32.985      0.000    -947.864    -841.536
# Source_Chennai          -504.3995     27.641    -18.248      0.000    -558.576    -450.223
# Source_Delhi            1158.7878     25.445     45.541      0.000    1108.915    1208.660
# Source_Hyderabad         432.1147     26.520     16.294      0.000     380.135     484.094
# Source_Kolkata          2950.6941     26.813    110.045      0.000    2898.140    3003.248
# Source_Mumbai           -140.7697     26.938     -5.226      0.000    -193.568     -87.971
# Departure_12 PM - 6 PM   770.9715     23.977     32.155      0.000     723.977     817.966
# Departure_6 AM - 12 PM  1143.2837     24.351     46.950      0.000    1095.555    1191.012
# Departure_After 6 PM     488.2884     27.185     17.962      0.000     435.006     541.571
# Departure_Before 6 AM    852.6493     31.992     26.652      0.000     789.945     915.353
# Total_stops_1-stop      1284.9309     52.379     24.532      0.000    1182.269    1387.593
# Total_stops_2+-stop     3660.3898    117.350     31.192      0.000    3430.383    3890.396
# Total_stops_non-stop   -1690.1278     58.133    -29.074      0.000   -1804.068   -1576.187
# Arrival_12 PM - 6 PM     912.7450     24.226     37.676      0.000     865.262     960.228
# Arrival_6 AM - 12 PM     453.7130     27.473     16.515      0.000     399.865     507.561
# Arrival_After 6 PM      1077.2169     23.228     46.376      0.000    1031.691    1122.743
# Arrival_Before 6 AM      811.5180     29.930     27.114      0.000     752.854     870.181
# Destination_Ahmedabad   -106.3218     33.301     -3.193      0.001    -171.593     -41.051
# Destination_Bangalore   -770.6979     26.567    -29.009      0.000    -822.770    -718.626
# Destination_Chennai      160.7872     27.641      5.817      0.000     106.611     214.964
# Destination_Delhi       1239.7192     25.961     47.753      0.000    1188.835    1290.603
# Destination_Hyderabad     83.6495     25.681      3.257      0.001      33.316     133.983
# Destination_Kolkata     2405.2265     26.542     90.618      0.000    2353.203    2457.250
# Destination_Mumbai       242.8302     26.352      9.215      0.000     191.181     294.479
# ==============================================================================
# Omnibus:                    26337.748   Durbin-Watson:                   0.604
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           193932.264
# Skew:                           1.757   Prob(JB):                         0.00
# Kurtosis:                      10.651   Cond. No.                     1.26e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.62e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x10, y10, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 1953.531151929112
# MSE: 7576717.943926527
# RMSE: 2752.5838668288616
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 1953.531
# Mean Squared Error (MSE): 7576717.944
# Root Mean Squared Error (RMSE): 2752.584
# R2_score: 0.411396
# Root Mean Squared Log Error (RMSLE): 7.92
# Mean Absolute Percentage Error (MAPE): 26.07 %
# Adj R Square:  0.410198
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 1539.938
# Mean Squared Error (MSE): 7487510.784
# Root Mean Squared Error (RMSE): 2736.332
# R2_score: 0.418327
# Root Mean Squared Log Error (RMSLE): 7.914
# Mean Absolute Percentage Error (MAPE): 17.7 %
# Adj R Square:  0.417143
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 1238.432
# Mean Squared Error (MSE): 4369202.841
# Root Mean Squared Error (RMSE): 2090.264
# R2_score: 0.660575
# Root Mean Squared Log Error (RMSLE): 7.645
# Mean Absolute Percentage Error (MAPE): 14.6 %
# Adj R Square:  0.659884
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 1596.873
# Mean Squared Error (MSE): 6067853.29
# Root Mean Squared Error (RMSE): 2463.301
# R2_score: 0.528614
# Root Mean Squared Log Error (RMSLE): 7.809
# Mean Absolute Percentage Error (MAPE): 19.19 %
# Adj R Square:  0.527655
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 1460.451
# Mean Squared Error (MSE): 6096989.923
# Root Mean Squared Error (RMSE): 2469.208
# R2_score: 0.52635
# Root Mean Squared Log Error (RMSLE): 7.812
# Mean Absolute Percentage Error (MAPE): 17.0 %
# Adj R Square:  0.525386
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 1664.418
# Mean Squared Error (MSE): 6092673.756
# Root Mean Squared Error (RMSE): 2468.334
# R2_score: 0.526686
# Root Mean Squared Log Error (RMSLE): 7.811
# Mean Absolute Percentage Error (MAPE): 21.33 %
# Adj R Square:  0.525723
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 1280.391
# Mean Squared Error (MSE): 4040701.601
# Root Mean Squared Error (RMSE): 2010.15
# R2_score: 0.686095
# Root Mean Squared Log Error (RMSLE): 7.606
# Mean Absolute Percentage Error (MAPE): 15.51 %
# Adj R Square:  0.685456
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 1295.069
# Mean Squared Error (MSE): 4758145.723
# Root Mean Squared Error (RMSE): 2181.317
# R2_score: 0.63036
# Root Mean Squared Log Error (RMSLE): 7.688
# Mean Absolute Percentage Error (MAPE): 15.27 %
# Adj R Square:  0.629608
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 1953.505
# Mean Squared Error (MSE): 7574876.008
# Root Mean Squared Error (RMSE): 2752.249
# R2_score: 0.41154
# Root Mean Squared Log Error (RMSLE): 7.92
# Mean Absolute Percentage Error (MAPE): 26.06 %
# Adj R Square:  0.410343
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 1953.445
# Mean Squared Error (MSE): 7574927.969
# Root Mean Squared Error (RMSE): 2752.259
# R2_score: 0.411536
# Root Mean Squared Log Error (RMSLE): 7.92
# Mean Absolute Percentage Error (MAPE): 26.06 %
# Adj R Square:  0.410339
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.626e+09, tolerance: 5.626e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1325364948.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %% [markdown]
# # Regressing Considering the data points where Class is Business

# %%
df_Business=df[df['Class_Business']==1]

# %%
y11=df_Business['Fare']
x11=df_Business.drop(['Date_of_journey_new','Fare','Journey_Month','Date_of_journey'],axis=1)

# %%
X=sm.add_constant(x11)
for i in X.columns:
    models=sm.OLS(y11,X[i])
    result = models.fit()
    print(f"Summary for {i}:\n{results.summary()}\n")
# Out:
# Summary for Duration_in_hours:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Days_left:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Friday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Monday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Saturday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Journey_day_Sunday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Thursday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Tuesday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Journey_day_Wednesday:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_Air India:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_AirAsia:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Airline_AkasaAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_AllianceAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_GO FIRST:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_Indigo:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_SpiceJet:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Airline_StarAir:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Airline_Vistara:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Class_Business:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Class_Economy:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Class_First:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Class_Premium Economy:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Ahmedabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Source_Bangalore:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:32   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# ...
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Ahmedabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Bangalore:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Chennai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Delhi:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Hyderabad:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary for Destination_Kolkata:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Summary for Destination_Mumbai:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.120
# Model:                            OLS   Adj. R-squared (uncentered):              0.120
# Method:                 Least Squares   F-statistic:                              8917.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        18:50:33   Log-Likelihood:                     -6.8642e+05
# No. Observations:               65659   AIC:                                  1.373e+06
# Df Residuals:                   65658   BIC:                                  1.373e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  7927.2430     83.949     94.429      0.000    7762.702    8091.784
# ==============================================================================
# Omnibus:                     2619.267   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7732.065
# Skew:                           0.124   Prob(JB):                         0.00
# Kurtosis:                       4.663   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y11=df_Business['Fare']
x11=df_Business.drop(['Date_of_journey_new','Fare','Journey_Month','Date_of_journey'],axis=1)
import statsmodels.api as sm
from statsmodels.api import add_constant
X=sm.add_constant(x11)
models=sm.OLS(y11, X)
result = models.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     3506.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        18:50:34   Log-Likelihood:            -1.3627e+06
# No. Observations:              126834   AIC:                         2.725e+06
# Df Residuals:                  126804   BIC:                         2.726e+06
# Df Model:                          29
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Duration_in_hours       -191.3425      5.966    -32.073      0.000    -203.035    -179.650
# Days_left               -227.5403      2.237   -101.697      0.000    -231.926    -223.155
# Journey_day_Friday      2645.5090     78.265     33.802      0.000    2492.111    2798.907
# Journey_day_Monday      3299.0524     73.611     44.817      0.000    3154.776    3443.329
# Journey_day_Saturday    2413.5823     78.168     30.877      0.000    2260.375    2566.789
# Journey_day_Sunday      3185.5614     79.255     40.194      0.000    3030.222    3340.901
# Journey_day_Thursday    2419.0656     78.486     30.821      0.000    2265.234    2572.897
# Journey_day_Tuesday     2938.8268     78.454     37.459      0.000    2785.058    3092.596
# Journey_day_Wednesday   3099.3353     77.536     39.973      0.000    2947.367    3251.304
# Airline_Air India       6136.0529     43.168    142.145      0.000    6051.445    6220.661
# Airline_AirAsia         2.132e-13   5.04e-14      4.226      0.000    1.14e-13    3.12e-13
# Airline_AkasaAir        8.011e-13   6.43e-14     12.451      0.000    6.75e-13    9.27e-13
# Airline_AllianceAir    -2.497e-12   5.84e-14    -42.781      0.000   -2.61e-12   -2.38e-12
# Airline_GO FIRST        6.866e-13   5.64e-14     12.178      0.000    5.76e-13    7.97e-13
# Airline_Indigo         -1.367e-13   4.66e-14     -2.932      0.003   -2.28e-13   -4.53e-14
# Airline_SpiceJet        2.732e-12   5.34e-14     51.204      0.000    2.63e-12    2.84e-12
# Airline_StarAir         2.705e-12   5.58e-14     48.506      0.000     2.6e-12    2.81e-12
# Airline_Vistara         1.386e+04     40.174    345.119      0.000    1.38e+04    1.39e+04
# Class_Business              2e+04     51.860    385.669      0.000    1.99e+04    2.01e+04
# Class_Economy           4.476e-13   3.46e-14     12.934      0.000     3.8e-13    5.15e-13
# Class_First            -1.323e-12   3.99e-14    -33.193      0.000    -1.4e-12   -1.25e-12
# Class_Premium Economy   7.911e-13   3.53e-14     22.429      0.000    7.22e-13     8.6e-13
# Source_Ahmedabad       -1413.0236     95.884    -14.737      0.000   -1600.955   -1225.092
# Source_Bangalore        5589.8139     75.756     73.787      0.000    5441.333    5738.294
# Source_Chennai          3826.4383     83.584     45.779      0.000    3662.614    3990.262
# Source_Delhi           -1642.5329     72.929    -22.522      0.000   -1785.472   -1499.594
# Source_Hyderabad         788.5172     85.546      9.217      0.000     620.849     956.185
# Source_Kolkata          9281.6828     86.821    106.906      0.000    9111.515    9451.851
# Source_Mumbai           3570.0371     71.061     50.239      0.000    3430.759    3709.315
# Departure_12 PM - 6 PM  6123.3656     67.804     90.310      0.000    5990.472    6256.260
# Departure_6 AM - 12 PM  4768.7404     60.406     78.945      0.000    4650.346    4887.135
# Departure_After 6 PM    6236.5768     68.059     91.634      0.000    6103.182    6369.972
# Departure_Before 6 AM   2872.2499    138.974     20.668      0.000    2599.863    3144.637
# Total_stops_1-stop      1.136e+04    100.463    113.125      0.000    1.12e+04    1.16e+04
# Total_stops_2+-stop     2.381e+04    207.165    114.908      0.000    2.34e+04    2.42e+04
# Total_stops_non-stop   -1.517e+04    123.000   -123.324      0.000   -1.54e+04   -1.49e+04
# Arrival_12 PM - 6 PM    7189.7842     65.676    109.473      0.000    7061.059    7318.509
# Arrival_6 AM - 12 PM    3634.3225     63.793     56.971      0.000    3509.289    3759.356
# Arrival_After 6 PM      6998.5106     55.150    126.900      0.000    6890.418    7106.603
# Arrival_Before 6 AM     2178.3153    114.789     18.977      0.000    1953.331    2403.300
# Destination_Ahmedabad  -2676.0696     94.289    -28.381      0.000   -2860.875   -2491.264
# Destination_Bangalore   5550.4036     76.859     72.216      0.000    5399.762    5701.045
# Destination_Chennai     4229.1441     82.298     51.388      0.000    4067.842    4390.446
# Destination_Delhi       -713.8053     75.178     -9.495      0.000    -861.152    -566.458
# Destination_Hyderabad    833.7671     81.752     10.199      0.000     673.534     994.000
# Destination_Kolkata     8709.6930     87.011    100.099      0.000    8539.153    8880.233
# Destination_Mumbai      4067.8000     71.048     57.254      0.000    3928.547    4207.053
# ==============================================================================
# Omnibus:                    14769.376   Durbin-Watson:                   0.362
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27539.463
# Skew:                           0.770   Prob(JB):                         0.00
# Kurtosis:                       4.685   Cond. No.                     1.38e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.86e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x11, y11, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 8462.35751146789
# MSE: 126954263.39043386
# RMSE: 11267.398252943483
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 8462.358
# Mean Squared Error (MSE): 126954263.39
# Root Mean Squared Error (RMSE): 11267.398
# R2_score: 0.44445
# Root Mean Squared Log Error (RMSLE): 9.33
# Mean Absolute Percentage Error (MAPE): 17.52 %
# Adj R Square:  0.443825
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 7419.755
# Mean Squared Error (MSE): 152560844.436
# Root Mean Squared Error (RMSE): 12351.552
# R2_score: 0.332396
# Root Mean Squared Log Error (RMSLE): 9.422
# Mean Absolute Percentage Error (MAPE): 14.41 %
# Adj R Square:  0.331645
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 6209.792
# Mean Squared Error (MSE): 92522159.946
# Root Mean Squared Error (RMSE): 9618.844
# R2_score: 0.595124
# Root Mean Squared Log Error (RMSLE): 9.171
# Mean Absolute Percentage Error (MAPE): 12.13 %
# Adj R Square:  0.594669
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 6384.192
# Mean Squared Error (MSE): 94223338.426
# Root Mean Squared Error (RMSE): 9706.871
# R2_score: 0.58768
# Root Mean Squared Log Error (RMSLE): 9.181
# Mean Absolute Percentage Error (MAPE): 12.37 %
# Adj R Square:  0.587216
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 6009.989
# Mean Squared Error (MSE): 97639460.772
# Root Mean Squared Error (RMSE): 9881.268
# R2_score: 0.572731
# Root Mean Squared Log Error (RMSLE): 9.198
# Mean Absolute Percentage Error (MAPE): 11.61 %
# Adj R Square:  0.572251
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 7474.692
# Mean Squared Error (MSE): 107177132.127
# Root Mean Squared Error (RMSE): 10352.639
# R2_score: 0.530995
# Root Mean Squared Log Error (RMSLE): 9.245
# Mean Absolute Percentage Error (MAPE): 14.9 %
# Adj R Square:  0.530468
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 6705.161
# Mean Squared Error (MSE): 90737056.648
# Root Mean Squared Error (RMSE): 9525.6
# R2_score: 0.602936
# Root Mean Squared Log Error (RMSLE): 9.162
# Mean Absolute Percentage Error (MAPE): 13.18 %
# Adj R Square:  0.60249
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 6347.468
# Mean Squared Error (MSE): 97454882.506
# Root Mean Squared Error (RMSE): 9871.924
# R2_score: 0.573539
# Root Mean Squared Log Error (RMSLE): 9.197
# Mean Absolute Percentage Error (MAPE): 12.39 %
# Adj R Square:  0.57306
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 8460.064
# Mean Squared Error (MSE): 126949757.598
# Root Mean Squared Error (RMSE): 11267.198
# R2_score: 0.44447
# Root Mean Squared Log Error (RMSLE): 9.33
# Mean Absolute Percentage Error (MAPE): 17.52 %
# Adj R Square:  0.443845
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 8460.061
# Mean Squared Error (MSE): 126950061.035
# Root Mean Squared Error (RMSE): 11267.212
# R2_score: 0.444469
# Root Mean Squared Log Error (RMSLE): 9.33
# Mean Absolute Percentage Error (MAPE): 17.52 %
# Adj R Square:  0.443844
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.518e+11, tolerance: 1.918e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1290633744.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %% [markdown]
# # Considering Complete Data Set removing First CLass and Premium Economy

# %%
y12=df['Fare']
x12=df.drop(['Date_of_journey_new','Fare','Journey_Month','Date_of_journey','Class_First','Class_Premium Economy'],axis=1)
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x12, y12, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 5131.344352838662
# MSE: 60905591.509122595
# RMSE: 7804.203451289734
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 5131.344
# Mean Squared Error (MSE): 60905591.509
# Root Mean Squared Error (RMSE): 7804.203
# R2_score: 0.852165
# Root Mean Squared Log Error (RMSLE): 8.962
# Mean Absolute Percentage Error (MAPE): 32.3 %
# Adj R Square:  0.85212
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 2538.099
# Mean Squared Error (MSE): 34201196.675
# Root Mean Squared Error (RMSE): 5848.179
# R2_score: 0.916984
# Root Mean Squared Log Error (RMSLE): 8.674
# Mean Absolute Percentage Error (MAPE): 11.67 %
# Adj R Square:  0.916959
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 2135.821
# Mean Squared Error (MSE): 18927328.292
# Root Mean Squared Error (RMSE): 4350.555
# R2_score: 0.954058
# Root Mean Squared Log Error (RMSLE): 8.378
# Mean Absolute Percentage Error (MAPE): 10.0 %
# Adj R Square:  0.954044
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 3335.288
# Mean Squared Error (MSE): 36877579.974
# Root Mean Squared Error (RMSE): 6072.691
# R2_score: 0.910488
# Root Mean Squared Log Error (RMSLE): 8.712
# Mean Absolute Percentage Error (MAPE): 16.89 %
# Adj R Square:  0.910461
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 2405.862
# Mean Squared Error (MSE): 26051984.036
# Root Mean Squared Error (RMSE): 5104.114
# R2_score: 0.936765
# Root Mean Squared Log Error (RMSLE): 8.538
# Mean Absolute Percentage Error (MAPE): 11.37 %
# Adj R Square:  0.936746
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 3997.783
# Mean Squared Error (MSE): 42127534.991
# Root Mean Squared Error (RMSE): 6490.573
# R2_score: 0.897745
# Root Mean Squared Log Error (RMSLE): 8.778
# Mean Absolute Percentage Error (MAPE): 21.65 %
# Adj R Square:  0.897714
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 3037.381
# Mean Squared Error (MSE): 26313331.153
# Root Mean Squared Error (RMSE): 5129.652
# R2_score: 0.93613
# Root Mean Squared Log Error (RMSLE): 8.543
# Mean Absolute Percentage Error (MAPE): 15.83 %
# Adj R Square:  0.936111
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 2225.489
# Mean Squared Error (MSE): 20828262.661
# Root Mean Squared Error (RMSE): 4563.799
# R2_score: 0.949444
# Root Mean Squared Log Error (RMSLE): 8.426
# Mean Absolute Percentage Error (MAPE): 10.46 %
# Adj R Square:  0.949429
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 5128.463
# Mean Squared Error (MSE): 60884498.383
# Root Mean Squared Error (RMSE): 7802.852
# R2_score: 0.852217
# Root Mean Squared Log Error (RMSLE): 8.962
# Mean Absolute Percentage Error (MAPE): 32.2 %
# Adj R Square:  0.852172
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 5128.29
# Mean Squared Error (MSE): 60884607.728
# Root Mean Squared Error (RMSE): 7802.859
# R2_score: 0.852216
# Root Mean Squared Log Error (RMSLE): 8.962
# Mean Absolute Percentage Error (MAPE): 32.19 %
# Adj R Square:  0.852171
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\2132037566.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %%
X= sm.add_constant(x12)

# %%
for i in X.columns:
    models=sm.OLS(y12, X[i])
    result=models.fit()
    print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                nan
# Time:                        19:20:38   Log-Likelihood:            -5.1256e+06
# No. Observations:              452088   AIC:                         1.025e+07
# Df Residuals:                  452087   BIC:                         1.025e+07
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.284e+04     30.203    756.211      0.000    2.28e+04    2.29e+04
# ==============================================================================
# Omnibus:                    88145.139   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149354.489
# Skew:                           1.335   Prob(JB):                         0.00
# Kurtosis:                       3.896   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.493
# Model:                            OLS   Adj. R-squared (uncentered):              0.493
# Method:                 Least Squares   F-statistic:                          4.391e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:38   Log-Likelihood:                     -5.1570e+06
# No. Observations:              452088   AIC:                                  1.031e+07
# Df Residuals:                  452087   BIC:                                  1.031e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Duration_in_hours  1488.5134      2.246    662.684      0.000    1484.111    1492.916
# ==============================================================================
# Omnibus:                    49171.676   Durbin-Watson:                   0.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            68062.186
# Skew:                           0.873   Prob(JB):                         0.00
# Kurtosis:                       3.752   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.390
# Model:                            OLS   Adj. R-squared (uncentered):              0.390
# Method:                 Least Squares   F-statistic:                          2.885e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:38   Log-Likelihood:                     -5.1989e+06
# No. Observations:              452088   AIC:                                  1.040e+07
# Df Residuals:                  452087   BIC:                                  1.040e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Days_left    649.9802      1.210    537.123      0.000     647.608     652.352
# ==============================================================================
# Omnibus:                    61820.498   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            91422.821
# Skew:                           1.021   Prob(JB):                         0.00
# Kurtosis:                       3.825   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.078
# Model:                            OLS   Adj. R-squared (uncentered):              0.078
# Method:                 Least Squares   F-statistic:                          3.810e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:38   Log-Likelihood:                     -5.2922e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Friday  2.266e+04    116.082    195.182      0.000    2.24e+04    2.29e+04
# ==============================================================================
# Omnibus:                    57821.377   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            83125.309
# Skew:                           0.987   Prob(JB):                         0.00
# Kurtosis:                       3.721   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.091
# Model:                            OLS   Adj. R-squared (uncentered):              0.091
# Method:                 Least Squares   F-statistic:                          4.547e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2888e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Monday  2.312e+04    108.406    213.238      0.000    2.29e+04    2.33e+04
# ==============================================================================
# Omnibus:                    53404.495   Durbin-Watson:                   0.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            74834.769
# Skew:                           0.938   Prob(JB):                         0.00
# Kurtosis:                       3.676   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.078
# Model:                            OLS   Adj. R-squared (uncentered):              0.078
# Method:                 Least Squares   F-statistic:                          3.841e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2920e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Journey_day_Saturday    2.3e+04    117.352    195.974      0.000    2.28e+04    2.32e+04
# ==============================================================================
# Omnibus:                    58613.830   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84771.092
# Skew:                           0.993   Prob(JB):                         0.00
# Kurtosis:                       3.747   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.078
# Model:                            OLS   Adj. R-squared (uncentered):              0.078
# Method:                 Least Squares   F-statistic:                          3.839e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2920e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Journey_day_Sunday  2.306e+04    117.700    195.923      0.000    2.28e+04    2.33e+04
# ==============================================================================
# Omnibus:                    58380.304   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84172.286
# Skew:                           0.993   Prob(JB):                         0.00
# Kurtosis:                       3.722   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.075
# Model:                            OLS   Adj. R-squared (uncentered):              0.075
# Method:                 Least Squares   F-statistic:                          3.671e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2928e+06
# No. Observations:              452088   AIC:                                  1.059e+07
# Df Residuals:                  452087   BIC:                                  1.059e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Journey_day_Thursday  2.223e+04    116.015    191.602      0.000     2.2e+04    2.25e+04
# ==============================================================================
# Omnibus:                    57577.216   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            82605.038
# Skew:                           0.985   Prob(JB):                         0.00
# Kurtosis:                       3.709   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.077
# Model:                            OLS   Adj. R-squared (uncentered):              0.077
# Method:                 Least Squares   F-statistic:                          3.774e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2923e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Journey_day_Tuesday  2.265e+04    116.609    194.260      0.000    2.24e+04    2.29e+04
# ==============================================================================
# Omnibus:                    56072.662   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79769.372
# Skew:                           0.968   Prob(JB):                         0.00
# Kurtosis:                       3.697   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.081
# Model:                            OLS   Adj. R-squared (uncentered):              0.081
# Method:                 Least Squares   F-statistic:                          3.973e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2914e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Journey_day_Wednesday  2.314e+04    116.119    199.312      0.000    2.29e+04    2.34e+04
# ==============================================================================
# Omnibus:                    55924.172   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79525.191
# Skew:                           0.966   Prob(JB):                         0.00
# Kurtosis:                       3.702   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.206
# Model:                            OLS   Adj. R-squared (uncentered):              0.206
# Method:                 Least Squares   F-statistic:                          1.170e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:39   Log-Likelihood:                     -5.2584e+06
# No. Observations:              452088   AIC:                                  1.052e+07
# Df Residuals:                  452087   BIC:                                  1.052e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Airline_Air India  2.691e+04     78.689    342.036      0.000    2.68e+04    2.71e+04
# ==============================================================================
# Omnibus:                    66348.496   Durbin-Watson:                   0.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           110705.572
# Skew:                           0.991   Prob(JB):                         0.00
# Kurtosis:                       4.396   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.002
# Model:                            OLS   Adj. R-squared (uncentered):              0.002
# Method:                 Least Squares   F-statistic:                              850.5
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                   8.51e-187
# Time:                        19:20:39   Log-Likelihood:                     -5.3100e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_AirAsia  7092.2659    243.193     29.163      0.000    6615.614    7568.918
# ==============================================================================
# Omnibus:                    83947.897   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           138904.484
# Skew:                           1.293   Prob(JB):                         0.00
# Kurtosis:                       3.828   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              30.43
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                    3.46e-08
# Time:                        19:20:39   Log-Likelihood:                     -5.3104e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_AkasaAir  3570.0345    647.181      5.516      0.000    2301.579    4838.490
# ==============================================================================
# Omnibus:                    87770.808   Durbin-Watson:                   0.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           148408.162
# Skew:                           1.331   Prob(JB):                         0.00
# Kurtosis:                       3.890   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              6.995
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                     0.00817
# Time:                        19:20:40   Log-Likelihood:                     -5.3104e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Airline_AllianceAir  4077.5013   1541.677      2.645      0.008    1055.861    7099.141
# ==============================================================================
# Omnibus:                    88071.562   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149168.096
# Skew:                           1.334   Prob(JB):                         0.00
# Kurtosis:                       3.895   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.002
# Model:                            OLS   Adj. R-squared (uncentered):              0.002
# Method:                 Least Squares   F-statistic:                              743.0
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                   1.79e-163
# Time:                        19:20:40   Log-Likelihood:                     -5.3101e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_GO FIRST  8015.0750    294.040     27.258      0.000    7438.766    8591.384
# ==============================================================================
# Omnibus:                    85016.337   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           141526.095
# Skew:                           1.304   Prob(JB):                         0.00
# Kurtosis:                       3.846   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.010
# Model:                            OLS   Adj. R-squared (uncentered):              0.010
# Method:                 Least Squares   F-statistic:                              4775.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:40   Log-Likelihood:                     -5.3081e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Airline_Indigo  8198.7548    118.649     69.101      0.000    7966.206    8431.303
# ==============================================================================
# Omnibus:                    72356.424   Durbin-Watson:                   0.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           112139.035
# Skew:                           1.181   Prob(JB):                         0.00
# Kurtosis:                       3.610   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.001
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              413.2
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                    8.15e-92
# Time:                        19:20:40   Log-Likelihood:                     -5.3102e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Airline_SpiceJet  8109.7732    398.965     20.327      0.000    7327.814    8891.732
# ==============================================================================
# Omnibus:                    86414.814   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144994.249
# Skew:                           1.318   Prob(JB):                         0.00
# Kurtosis:                       3.867   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.000
# Method:                 Least Squares   F-statistic:                              6.365
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                      0.0116
# Time:                        19:20:40   Log-Likelihood:                     -5.3104e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_StarAir  9792.7742   3881.452      2.523      0.012    2185.247    1.74e+04
# ==============================================================================
# Omnibus:                    88123.209   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149299.150
# Skew:                           1.335   Prob(JB):                         0.00
# Kurtosis:                       3.896   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.407
# Model:                            OLS   Adj. R-squared (uncentered):              0.407
# Method:                 Least Squares   F-statistic:                          3.100e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:40   Log-Likelihood:                     -5.1924e+06
# No. Observations:              452088   AIC:                                  1.038e+07
# Df Residuals:                  452087   BIC:                                  1.038e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_Vistara  2.724e+04     48.925    556.783      0.000    2.71e+04    2.73e+04
# ==============================================================================
# Omnibus:                    32413.721   Durbin-Watson:                   0.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39999.597
# Skew:                           0.728   Prob(JB):                         0.00
# Kurtosis:                       2.965   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          1.830e+06
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:40   Log-Likelihood:                     -4.9445e+06
# No. Observations:              452088   AIC:                                  9.889e+06
# Df Residuals:                  452087   BIC:                                  9.889e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Class_Business  5.167e+04     38.200   1352.602      0.000    5.16e+04    5.17e+04
# ==============================================================================
# Omnibus:                    56263.609   Durbin-Watson:                   0.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           251897.404
# Skew:                          -0.544   Prob(JB):                         0.00
# Kurtosis:                       6.491   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.062
# Model:                            OLS   Adj. R-squared (uncentered):              0.062
# Method:                 Least Squares   F-statistic:                          2.997e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:40   Log-Likelihood:                     -5.2959e+06
# No. Observations:              452088   AIC:                                  1.059e+07
# Df Residuals:                  452087   BIC:                                  1.059e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Class_Economy  1.021e+04     58.956    173.128      0.000    1.01e+04    1.03e+04
# ==============================================================================
# Omnibus:                    61720.921   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            91263.248
# Skew:                           1.099   Prob(JB):                         0.00
# Kurtosis:                       3.130   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.054
# Model:                            OLS   Adj. R-squared (uncentered):              0.054
# Method:                 Least Squares   F-statistic:                          2.581e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:40   Log-Likelihood:                     -5.2979e+06
# No. Observations:              452088   AIC:                                  1.060e+07
# Df Residuals:                  452087   BIC:                                  1.060e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Ahmedabad  2.224e+04    138.440    160.643      0.000     2.2e+04    2.25e+04
# ==============================================================================
# Omnibus:                    66950.042   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           101250.958
# Skew:                           1.090   Prob(JB):                         0.00
# Kurtosis:                       3.789   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.093
# Model:                            OLS   Adj. R-squared (uncentered):              0.093
# Method:                 Least Squares   F-statistic:                          4.639e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:41   Log-Likelihood:                     -5.2884e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Source_Bangalore  2.314e+04    107.450    215.393      0.000    2.29e+04    2.34e+04
# ==============================================================================
# Omnibus:                    49461.906   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            67900.714
# Skew:                           0.889   Prob(JB):                         0.00
# Kurtosis:                       3.665   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.071
# Model:                            OLS   Adj. R-squared (uncentered):              0.071
# Method:                 Least Squares   F-statistic:                          3.477e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:41   Log-Likelihood:                     -5.2937e+06
# No. Observations:              452088   AIC:                                  1.059e+07
# Df Residuals:                  452087   BIC:                                  1.059e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Source_Chennai   2.31e+04    123.888    186.455      0.000    2.29e+04    2.33e+04
# ==============================================================================
# Omnibus:                    60073.704   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            87774.052
# Skew:                           1.006   Prob(JB):                         0.00
# Kurtosis:                       3.784   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.083
# Model:                            OLS   Adj. R-squared (uncentered):              0.083
# Method:                 Least Squares   F-statistic:                          4.080e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:41   Log-Likelihood:                     -5.2909e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# ...
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.021
# Model:                            OLS   Adj. R-squared (uncentered):              0.021
# Method:                 Least Squares   F-statistic:                              9688.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:42   Log-Likelihood:                     -5.3056e+06
# No. Observations:              452088   AIC:                                  1.061e+07
# Df Residuals:                  452087   BIC:                                  1.061e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Arrival_Before 6 AM  1.697e+04    172.409     98.430      0.000    1.66e+04    1.73e+04
# ==============================================================================
# Omnibus:                    73667.985   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           115313.415
# Skew:                           1.173   Prob(JB):                         0.00
# Kurtosis:                       3.785   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.048
# Model:                            OLS   Adj. R-squared (uncentered):              0.048
# Method:                 Least Squares   F-statistic:                          2.271e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2994e+06
# No. Observations:              452088   AIC:                                  1.060e+07
# Df Residuals:                  452087   BIC:                                  1.060e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Ahmedabad  2.132e+04    141.478    150.692      0.000     2.1e+04    2.16e+04
# ==============================================================================
# Omnibus:                    66528.691   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           100354.256
# Skew:                           1.086   Prob(JB):                         0.00
# Kurtosis:                       3.782   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.089
# Model:                            OLS   Adj. R-squared (uncentered):              0.089
# Method:                 Least Squares   F-statistic:                          4.422e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2893e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Bangalore  2.281e+04    108.449    210.295      0.000    2.26e+04     2.3e+04
# ==============================================================================
# Omnibus:                    50611.705   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            69852.251
# Skew:                           0.904   Prob(JB):                         0.00
# Kurtosis:                       3.661   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.077
# Model:                            OLS   Adj. R-squared (uncentered):              0.077
# Method:                 Least Squares   F-statistic:                          3.765e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2924e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Destination_Chennai  2.374e+04    122.364    194.039      0.000    2.35e+04     2.4e+04
# ==============================================================================
# Omnibus:                    59927.832   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            87590.336
# Skew:                           1.002   Prob(JB):                         0.00
# Kurtosis:                       3.796   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.081
# Model:                            OLS   Adj. R-squared (uncentered):              0.081
# Method:                 Least Squares   F-statistic:                          3.994e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2913e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Destination_Delhi    2.1e+04    105.073    199.856      0.000    2.08e+04    2.12e+04
# ==============================================================================
# Omnibus:                    58412.026   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84020.049
# Skew:                           0.999   Prob(JB):                         0.00
# Kurtosis:                       3.682   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.071
# Model:                            OLS   Adj. R-squared (uncentered):              0.071
# Method:                 Least Squares   F-statistic:                          3.461e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2938e+06
# No. Observations:              452088   AIC:                                  1.059e+07
# Df Residuals:                  452087   BIC:                                  1.059e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Destination_Hyderabad  2.191e+04    117.788    186.035      0.000    2.17e+04    2.21e+04
# ==============================================================================
# Omnibus:                    58868.988   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            85071.260
# Skew:                           1.000   Prob(JB):                         0.00
# Kurtosis:                       3.719   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.082
# Model:                            OLS   Adj. R-squared (uncentered):              0.082
# Method:                 Least Squares   F-statistic:                          4.029e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2911e+06
# No. Observations:              452088   AIC:                                  1.058e+07
# Df Residuals:                  452087   BIC:                                  1.058e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Destination_Kolkata  2.519e+04    125.508    200.711      0.000    2.49e+04    2.54e+04
# ==============================================================================
# Omnibus:                    56436.056   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            80565.900
# Skew:                           0.969   Prob(JB):                         0.00
# Kurtosis:                       3.719   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.113
# Model:                            OLS   Adj. R-squared (uncentered):              0.113
# Method:                 Least Squares   F-statistic:                          5.738e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:20:43   Log-Likelihood:                     -5.2834e+06
# No. Observations:              452088   AIC:                                  1.057e+07
# Df Residuals:                  452087   BIC:                                  1.057e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Destination_Mumbai  2.394e+04     99.936    239.531      0.000    2.37e+04    2.41e+04
# ==============================================================================
# Omnibus:                    49642.563   Durbin-Watson:                   0.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            67997.473
# Skew:                           0.897   Prob(JB):                         0.00
# Kurtosis:                       3.627   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Checking Fare wrt to Days Left and Duration In hrs

# %%
y12=df['Fare']
x12=df[['Duration_in_hours','Days_left']]

# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x12, y12, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 16226.926867910212
# MSE: 395690807.23390007
# RMSE: 19891.97846454445
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 16226.927
# Mean Squared Error (MSE): 395690807.234
# Root Mean Squared Error (RMSE): 19891.978
# R2_score: 0.03955
# Root Mean Squared Log Error (RMSLE): 9.898
# Mean Absolute Percentage Error (MAPE): 114.62 %
# Adj R Square:  0.039537
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 16005.966
# Mean Squared Error (MSE): 399546025.45
# Root Mean Squared Error (RMSE): 19988.647
# R2_score: 0.030192
# Root Mean Squared Log Error (RMSLE): 9.903
# Mean Absolute Percentage Error (MAPE): 103.48 %
# Adj R Square:  0.030179
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 15990.373
# Mean Squared Error (MSE): 398616220.145
# Root Mean Squared Error (RMSE): 19965.376
# R2_score: 0.032449
# Root Mean Squared Log Error (RMSLE): 9.902
# Mean Absolute Percentage Error (MAPE): 103.39 %
# Adj R Square:  0.032436
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 16535.543
# Mean Squared Error (MSE): 453628177.417
# Root Mean Squared Error (RMSE): 21298.549
# R2_score: -0.10108
# Root Mean Squared Log Error (RMSLE): 9.966
# Mean Absolute Percentage Error (MAPE): 107.34 %
# Adj R Square:  -0.101095
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 16006.884
# Mean Squared Error (MSE): 399413828.782
# Root Mean Squared Error (RMSE): 19985.34
# R2_score: 0.030513
# Root Mean Squared Log Error (RMSLE): 9.903
# Mean Absolute Percentage Error (MAPE): 103.5 %
# Adj R Square:  0.0305
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 15604.837
# Mean Squared Error (MSE): 370044951.264
# Root Mean Squared Error (RMSE): 19236.552
# R2_score: 0.101799
# Root Mean Squared Log Error (RMSLE): 9.865
# Mean Absolute Percentage Error (MAPE): 101.91 %
# Adj R Square:  0.101787
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 15557.488
# Mean Squared Error (MSE): 370153643.082
# Root Mean Squared Error (RMSE): 19239.377
# R2_score: 0.101535
# Root Mean Squared Log Error (RMSLE): 9.865
# Mean Absolute Percentage Error (MAPE): 100.93 %
# Adj R Square:  0.101523
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 16011.864
# Mean Squared Error (MSE): 400885539.709
# Root Mean Squared Error (RMSE): 20022.126
# R2_score: 0.026941
# Root Mean Squared Log Error (RMSLE): 9.905
# Mean Absolute Percentage Error (MAPE): 103.5 %
# Adj R Square:  0.026928
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 16226.955
# Mean Squared Error (MSE): 395690821.147
# Root Mean Squared Error (RMSE): 19891.979
# R2_score: 0.03955
# Root Mean Squared Log Error (RMSLE): 9.898
# Mean Absolute Percentage Error (MAPE): 114.62 %
# Adj R Square:  0.039537
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 16226.973
# Mean Squared Error (MSE): 395690846.899
# Root Mean Squared Error (RMSE): 19891.979
# R2_score: 0.039549
# Root Mean Squared Log Error (RMSLE): 9.898
# Mean Absolute Percentage Error (MAPE): 114.62 %
# Adj R Square:  0.039536
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\4232334557.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %%
# import pickle

# %%
# pickle.dump(scaler,open('scaled_data.pkl','wb'))

# %%
# Running with Class and Airlines

# %%
# Considering All the Airlines

# %%
y12=df['Fare']
x12=df[['Duration_in_hours','Days_left','Class_Economy','Class_Business','Airline_Air India','Airline_AirAsia','Airline_AkasaAir',
                'Airline_AllianceAir','Airline_GO FIRST',
                'Airline_Indigo','Airline_SpiceJet','Airline_StarAir','Airline_Vistara']]

# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x12, y12, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 5448.519481868758
# MSE: 72268294.26431899
# RMSE: 8501.076065082525
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 5448.519
# Mean Squared Error (MSE): 72268294.264
# Root Mean Squared Error (RMSE): 8501.076
# R2_score: 0.824585
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.02 %
# Adj R Square:  0.82457
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 4853.526
# Mean Squared Error (MSE): 62952780.507
# Root Mean Squared Error (RMSE): 7934.279
# R2_score: 0.847196
# Root Mean Squared Log Error (RMSLE): 8.979
# Mean Absolute Percentage Error (MAPE): 25.08 %
# Adj R Square:  0.847183
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 4655.815
# Mean Squared Error (MSE): 57116549.368
# Root Mean Squared Error (RMSE): 7557.549
# R2_score: 0.861362
# Root Mean Squared Log Error (RMSLE): 8.93
# Mean Absolute Percentage Error (MAPE): 24.09 %
# Adj R Square:  0.86135
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 4671.071
# Mean Squared Error (MSE): 55709883.545
# Root Mean Squared Error (RMSE): 7463.905
# R2_score: 0.864777
# Root Mean Squared Log Error (RMSLE): 8.918
# Mean Absolute Percentage Error (MAPE): 24.64 %
# Adj R Square:  0.864765
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 4849.19
# Mean Squared Error (MSE): 62347678.159
# Root Mean Squared Error (RMSE): 7896.055
# R2_score: 0.848665
# Root Mean Squared Log Error (RMSLE): 8.974
# Mean Absolute Percentage Error (MAPE): 25.09 %
# Adj R Square:  0.848652
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 4395.462
# Mean Squared Error (MSE): 48900067.334
# Root Mean Squared Error (RMSE): 6992.858
# R2_score: 0.881306
# Root Mean Squared Log Error (RMSLE): 8.853
# Mean Absolute Percentage Error (MAPE): 23.92 %
# Adj R Square:  0.881296
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 4110.416
# Mean Squared Error (MSE): 43923580.143
# Root Mean Squared Error (RMSE): 6627.487
# R2_score: 0.893385
# Root Mean Squared Log Error (RMSLE): 8.799
# Mean Absolute Percentage Error (MAPE): 21.87 %
# Adj R Square:  0.893376
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 4699.038
# Mean Squared Error (MSE): 58355955.36
# Root Mean Squared Error (RMSE): 7639.107
# R2_score: 0.858354
# Root Mean Squared Log Error (RMSLE): 8.941
# Mean Absolute Percentage Error (MAPE): 24.28 %
# Adj R Square:  0.858342
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 5448.12
# Mean Squared Error (MSE): 72267978.76
# Root Mean Squared Error (RMSE): 8501.058
# R2_score: 0.824586
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.0 %
# Adj R Square:  0.824571
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 5448.109
# Mean Squared Error (MSE): 72268056.515
# Root Mean Squared Error (RMSE): 8501.062
# R2_score: 0.824586
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.0 %
# Adj R Square:  0.824571
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.818e+12, tolerance: 1.250e+10
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\147347331.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %%
# Considering the major airlines

# %%
y12=df['Fare']
x12=df[['Duration_in_hours','Days_left','Class_Economy','Class_Business','Airline_Air India','Airline_AirAsia',
                'Airline_GO FIRST',
                'Airline_Indigo','Airline_SpiceJet','Airline_Vistara']]

# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x12, y12, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 5448.377595898038
# MSE: 72272032.96486959
# RMSE: 8501.295957962502
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 5448.378
# Mean Squared Error (MSE): 72272032.965
# Root Mean Squared Error (RMSE): 8501.296
# R2_score: 0.824576
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.0 %
# Adj R Square:  0.824564
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 4854.063
# Mean Squared Error (MSE): 62956577.627
# Root Mean Squared Error (RMSE): 7934.518
# R2_score: 0.847187
# Root Mean Squared Log Error (RMSLE): 8.979
# Mean Absolute Percentage Error (MAPE): 25.1 %
# Adj R Square:  0.847177
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 4656.235
# Mean Squared Error (MSE): 57075836.043
# Root Mean Squared Error (RMSE): 7554.855
# R2_score: 0.861461
# Root Mean Squared Log Error (RMSLE): 8.93
# Mean Absolute Percentage Error (MAPE): 24.11 %
# Adj R Square:  0.861452
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 4671.154
# Mean Squared Error (MSE): 55709760.395
# Root Mean Squared Error (RMSE): 7463.897
# R2_score: 0.864777
# Root Mean Squared Log Error (RMSLE): 8.918
# Mean Absolute Percentage Error (MAPE): 24.65 %
# Adj R Square:  0.864768
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 4848.742
# Mean Squared Error (MSE): 62326854.918
# Root Mean Squared Error (RMSE): 7894.736
# R2_score: 0.848716
# Root Mean Squared Log Error (RMSLE): 8.974
# Mean Absolute Percentage Error (MAPE): 25.1 %
# Adj R Square:  0.848706
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 4396.453
# Mean Squared Error (MSE): 48936826.902
# Root Mean Squared Error (RMSE): 6995.486
# R2_score: 0.881217
# Root Mean Squared Log Error (RMSLE): 8.853
# Mean Absolute Percentage Error (MAPE): 23.9 %
# Adj R Square:  0.881209
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 4100.053
# Mean Squared Error (MSE): 43720619.036
# Root Mean Squared Error (RMSE): 6612.157
# R2_score: 0.893878
# Root Mean Squared Log Error (RMSLE): 8.797
# Mean Absolute Percentage Error (MAPE): 21.82 %
# Adj R Square:  0.893871
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 4705.484
# Mean Squared Error (MSE): 58377017.906
# Root Mean Squared Error (RMSE): 7640.485
# R2_score: 0.858303
# Root Mean Squared Log Error (RMSLE): 8.941
# Mean Absolute Percentage Error (MAPE): 24.35 %
# Adj R Square:  0.858294
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 5448.357
# Mean Squared Error (MSE): 72272012.039
# Root Mean Squared Error (RMSE): 8501.295
# R2_score: 0.824576
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.0 %
# Adj R Square:  0.824564
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 5448.336
# Mean Squared Error (MSE): 72272150.398
# Root Mean Squared Error (RMSE): 8501.303
# R2_score: 0.824576
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.0 %
# Adj R Square:  0.824564
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\1313200995.py:95: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %%
y12=df['Fare']
x12=df[['Duration_in_hours','Days_left','Class_Economy','Class_Business','Airline_Air India',
                'Airline_Indigo','Airline_Vistara']]

# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(x12, y12, test_size=0.33, random_state=42)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
reg.fit(X_train,y_train)
pred=reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))


# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(X_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(X_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_train.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    Results = Results.append(new_row, ignore_index=True)
# Out:
# MAE: 5453.246125704791
# MSE: 72315363.66716246
# RMSE: 8503.84405237787
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 5453.246
# Mean Squared Error (MSE): 72315363.667
# Root Mean Squared Error (RMSE): 8503.844
# R2_score: 0.824471
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.11 %
# Adj R Square:  0.824463
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 4866.298
# Mean Squared Error (MSE): 62956446.311
# Root Mean Squared Error (RMSE): 7934.51
# R2_score: 0.847187
# Root Mean Squared Log Error (RMSLE): 8.979
# Mean Absolute Percentage Error (MAPE): 25.33 %
# Adj R Square:  0.84718
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 4678.469
# Mean Squared Error (MSE): 57299856.804
# Root Mean Squared Error (RMSE): 7569.667
# R2_score: 0.860917
# Root Mean Squared Log Error (RMSLE): 8.932
# Mean Absolute Percentage Error (MAPE): 24.46 %
# Adj R Square:  0.86091
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  KNeighborsRegressor()
# Mean Absolute Error (MAE): 4679.361
# Mean Squared Error (MSE): 55779295.455
# Root Mean Squared Error (RMSE): 7468.554
# R2_score: 0.864608
# Root Mean Squared Log Error (RMSLE): 8.918
# Mean Absolute Percentage Error (MAPE): 24.77 %
# Adj R Square:  0.864602
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  ExtraTreesRegressor()
# Mean Absolute Error (MAE): 4862.907
# Mean Squared Error (MSE): 62400541.99
# Root Mean Squared Error (RMSE): 7899.401
# R2_score: 0.848537
# Root Mean Squared Log Error (RMSLE): 8.975
# Mean Absolute Percentage Error (MAPE): 25.35 %
# Adj R Square:  0.84853
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  GradientBoostingRegressor()
# Mean Absolute Error (MAE): 4406.198
# Mean Squared Error (MSE): 48971080.928
# Root Mean Squared Error (RMSE): 6997.934
# R2_score: 0.881134
# Root Mean Squared Log Error (RMSLE): 8.853
# Mean Absolute Percentage Error (MAPE): 24.07 %
# Adj R Square:  0.881128
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# Mean Absolute Error (MAE): 4116.081
# Mean Squared Error (MSE): 43942068.711
# Root Mean Squared Error (RMSE): 6628.881
# R2_score: 0.893341
# Root Mean Squared Log Error (RMSLE): 8.799
# Mean Absolute Percentage Error (MAPE): 22.01 %
# Adj R Square:  0.893336
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  BaggingRegressor()
# Mean Absolute Error (MAE): 4725.377
# Mean Squared Error (MSE): 58658403.925
# Root Mean Squared Error (RMSE): 7658.877
# R2_score: 0.85762
# Root Mean Squared Log Error (RMSLE): 8.944
# Mean Absolute Percentage Error (MAPE): 24.68 %
# Adj R Square:  0.857613
# ------------------------------------------------------------------------------------------------------------
# Model Name:  Ridge()
# Mean Absolute Error (MAE): 5453.225
# Mean Squared Error (MSE): 72315333.358
# Root Mean Squared Error (RMSE): 8503.842
# R2_score: 0.824471
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.11 %
# Adj R Square:  0.824463
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)
# Model Name:  Lasso(alpha=0.1)
# Mean Absolute Error (MAE): 5453.192
# Mean Squared Error (MSE): 72315320.776
# Root Mean Squared Error (RMSE): 8503.842
# R2_score: 0.824471
# Root Mean Squared Log Error (RMSLE): 9.048
# Mean Absolute Percentage Error (MAPE): 32.12 %
# Adj R Square:  0.824463
# ------------------------------------------------------------------------------------------------------------
# C:\Users\abhi9\AppData\Local\Temp\ipykernel_22624\500723650.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Results = Results.append(new_row, ignore_index=True)

# %%
# Univariate Analysis for the above

# %%
y12=df['Fare']
x12=df[['Duration_in_hours','Days_left','Class_Economy','Class_Business','Airline_Air India',
                'Airline_Indigo','Airline_Vistara']]

# %%
X= sm.add_constant(x12)

# %%
for i in X.columns:
    models = sm.OLS(y12,X[i])
    result= models.fit()
    print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                nan
# Time:                        19:48:41   Log-Likelihood:            -5.1256e+06
# No. Observations:              452088   AIC:                         1.025e+07
# Df Residuals:                  452087   BIC:                         1.025e+07
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.284e+04     30.203    756.211      0.000    2.28e+04    2.29e+04
# ==============================================================================
# Omnibus:                    88145.139   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149354.489
# Skew:                           1.335   Prob(JB):                         0.00
# Kurtosis:                       3.896   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.493
# Model:                            OLS   Adj. R-squared (uncentered):              0.493
# Method:                 Least Squares   F-statistic:                          4.391e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:43   Log-Likelihood:                     -5.1570e+06
# No. Observations:              452088   AIC:                                  1.031e+07
# Df Residuals:                  452087   BIC:                                  1.031e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Duration_in_hours  1488.5134      2.246    662.684      0.000    1484.111    1492.916
# ==============================================================================
# Omnibus:                    49171.676   Durbin-Watson:                   0.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            68062.186
# Skew:                           0.873   Prob(JB):                         0.00
# Kurtosis:                       3.752   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.390
# Model:                            OLS   Adj. R-squared (uncentered):              0.390
# Method:                 Least Squares   F-statistic:                          2.885e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:43   Log-Likelihood:                     -5.1989e+06
# No. Observations:              452088   AIC:                                  1.040e+07
# Df Residuals:                  452087   BIC:                                  1.040e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Days_left    649.9802      1.210    537.123      0.000     647.608     652.352
# ==============================================================================
# Omnibus:                    61820.498   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            91422.821
# Skew:                           1.021   Prob(JB):                         0.00
# Kurtosis:                       3.825   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.062
# Model:                            OLS   Adj. R-squared (uncentered):              0.062
# Method:                 Least Squares   F-statistic:                          2.997e+04
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:43   Log-Likelihood:                     -5.2959e+06
# No. Observations:              452088   AIC:                                  1.059e+07
# Df Residuals:                  452087   BIC:                                  1.059e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Class_Economy  1.021e+04     58.956    173.128      0.000    1.01e+04    1.03e+04
# ==============================================================================
# Omnibus:                    61720.921   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            91263.248
# Skew:                           1.099   Prob(JB):                         0.00
# Kurtosis:                       3.130   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          1.830e+06
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:44   Log-Likelihood:                     -4.9445e+06
# No. Observations:              452088   AIC:                                  9.889e+06
# Df Residuals:                  452087   BIC:                                  9.889e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Class_Business  5.167e+04     38.200   1352.602      0.000    5.16e+04    5.17e+04
# ==============================================================================
# Omnibus:                    56263.609   Durbin-Watson:                   0.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           251897.404
# Skew:                          -0.544   Prob(JB):                         0.00
# Kurtosis:                       6.491   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.206
# Model:                            OLS   Adj. R-squared (uncentered):              0.206
# Method:                 Least Squares   F-statistic:                          1.170e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:44   Log-Likelihood:                     -5.2584e+06
# No. Observations:              452088   AIC:                                  1.052e+07
# Df Residuals:                  452087   BIC:                                  1.052e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Airline_Air India  2.691e+04     78.689    342.036      0.000    2.68e+04    2.71e+04
# ==============================================================================
# Omnibus:                    66348.496   Durbin-Watson:                   0.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           110705.572
# Skew:                           0.991   Prob(JB):                         0.00
# Kurtosis:                       4.396   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.010
# Model:                            OLS   Adj. R-squared (uncentered):              0.010
# Method:                 Least Squares   F-statistic:                              4775.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:44   Log-Likelihood:                     -5.3081e+06
# No. Observations:              452088   AIC:                                  1.062e+07
# Df Residuals:                  452087   BIC:                                  1.062e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Airline_Indigo  8198.7548    118.649     69.101      0.000    7966.206    8431.303
# ==============================================================================
# Omnibus:                    72356.424   Durbin-Watson:                   0.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           112139.035
# Skew:                           1.181   Prob(JB):                         0.00
# Kurtosis:                       3.610   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Fare   R-squared (uncentered):                   0.407
# Model:                            OLS   Adj. R-squared (uncentered):              0.407
# Method:                 Least Squares   F-statistic:                          3.100e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        19:48:44   Log-Likelihood:                     -5.1924e+06
# No. Observations:              452088   AIC:                                  1.038e+07
# Df Residuals:                  452087   BIC:                                  1.038e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Airline_Vistara  2.724e+04     48.925    556.783      0.000    2.71e+04    2.73e+04
# ==============================================================================
# Omnibus:                    32413.721   Durbin-Watson:                   0.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39999.597
# Skew:                           0.728   Prob(JB):                         0.00
# Kurtosis:                       2.965   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
models = sm.OLS(y12,X)
result= models.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                 3.026e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        19:48:46   Log-Likelihood:            -4.7328e+06
# No. Observations:              452088   AIC:                         9.466e+06
# Df Residuals:                  452080   BIC:                         9.466e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              1.181e+04     68.393    172.685      0.000    1.17e+04    1.19e+04
# Duration_in_hours   203.4374      1.905    106.773      0.000     199.703     207.172
# Days_left          -148.7787      0.887   -167.812      0.000    -150.516    -147.041
# Class_Economy     -2510.0234     41.096    -61.077      0.000   -2590.570   -2429.477
# Class_Business      3.75e+04     41.954    893.877      0.000    3.74e+04    3.76e+04
# Airline_Air India  1059.6691     54.748     19.355      0.000     952.365    1166.973
# Airline_Indigo     1614.6904     56.718     28.468      0.000    1503.524    1725.857
# Airline_Vistara    5258.9670     53.272     98.720      0.000    5154.556    5363.378
# ==============================================================================
# Omnibus:                   103875.774   Durbin-Watson:                   0.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           966280.486
# Skew:                           0.844   Prob(JB):                         0.00
# Kurtosis:                       9.961   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Adding Stops as another independent Variable

# %%
y13=df['Fare']
x13=df[['Duration_in_hours','Days_left','Class_Economy','Class_Business','Airline_Air India',
                'Airline_Indigo','Airline_Vistara','Total_stops_2+-stop','Total_stops_1-stop','Total_stops_non-stop']]

# %%
X= sm.add_constant(x13)
models = sm.OLS(y13,X)
result= models.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.840
# Method:                 Least Squares   F-statistic:                 2.374e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        19:48:47   Log-Likelihood:            -4.7113e+06
# No. Observations:              452088   AIC:                         9.423e+06
# Df Residuals:                  452077   BIC:                         9.423e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -1.005e+13   6.52e+13     -0.154      0.877   -1.38e+14    1.18e+14
# Duration_in_hours       -5.1337      2.069     -2.481      0.013      -9.189      -1.078
# Days_left             -152.8187      0.846   -180.674      0.000    -154.477    -151.161
# Class_Economy        -2818.0551     39.234    -71.827      0.000   -2894.953   -2741.157
# Class_Business        3.737e+04     40.429    924.276      0.000    3.73e+04    3.74e+04
# Airline_Air India      616.7572     52.256     11.803      0.000     514.336     719.178
# Airline_Indigo        1082.8841     54.196     19.981      0.000     976.661    1189.107
# Airline_Vistara       4509.3304     50.929     88.541      0.000    4409.511    4609.150
# Total_stops_2+-stop   1.005e+13   6.52e+13      0.154      0.877   -1.18e+14    1.38e+14
# Total_stops_1-stop    1.005e+13   6.52e+13      0.154      0.877   -1.18e+14    1.38e+14
# Total_stops_non-stop  1.005e+13   6.52e+13      0.154      0.877   -1.18e+14    1.38e+14
# ==============================================================================
# Omnibus:                   131039.876   Durbin-Watson:                   0.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1113963.526
# Skew:                           1.156   Prob(JB):                         0.00
# Kurtosis:                      10.334   Cond. No.                     3.39e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.88e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
y14=df['Fare']
x14=df[['Duration_in_hours','Days_left','Class_Economy','Class_Business','Airline_Air India',
                'Airline_Indigo','Airline_Vistara','Total_stops_non-stop']]

# %%
X= sm.add_constant(x14)
models = sm.OLS(y14,X)
result= models.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                 2.948e+05
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        19:48:48   Log-Likelihood:            -4.7126e+06
# No. Observations:              452088   AIC:                         9.425e+06
# Df Residuals:                  452079   BIC:                         9.425e+06
# Df Model:                           8
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1.616e+04     68.740    235.083      0.000     1.6e+04    1.63e+04
# Duration_in_hours       11.1844      2.048      5.461      0.000       7.170      15.198
# Days_left             -152.0573      0.848   -179.317      0.000    -153.719    -150.395
# Class_Economy        -2851.8554     39.335    -72.502      0.000   -2928.951   -2774.760
# Class_Business         3.71e+04     40.169    923.514      0.000     3.7e+04    3.72e+04
# Airline_Air India      659.3745     52.391     12.586      0.000     556.689     762.060
# Airline_Indigo        1005.6448     54.320     18.513      0.000     899.178    1112.111
# Airline_Vistara       4560.8262     51.057     89.329      0.000    4460.757    4660.896
# Total_stops_non-stop -9037.2432     43.957   -205.593      0.000   -9123.398   -8951.089
# ==============================================================================
# Omnibus:                   130858.211   Durbin-Watson:                   0.289
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1097387.245
# Skew:                           1.158   Prob(JB):                         0.00
# Kurtosis:                      10.273   Cond. No.                         259.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Neural Network

# %%
import tensorflow as tf

# %%
y12= df['Fare'].values
x12= df.drop(['Fare','Date_of_journey','Date_of_journey_new','Journey_Month'],axis=1).values

# # ----------------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(x12, y12, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[13.5   , 32.    ,  0.    , ...,  0.    ,  0.    ,  1.    ],
#        [ 4.8333, 41.    ,  0.    , ...,  1.    ,  0.    ,  0.    ],
#        [23.1667,  7.    ,  0.    , ...,  0.    ,  0.    ,  1.    ],
#        ...,
#        [10.4167, 12.    ,  1.    , ...,  0.    ,  1.    ,  0.    ],
#        [10.    , 26.    ,  1.    , ...,  0.    ,  0.    ,  0.    ],
#        [13.6667, 25.    ,  0.    , ...,  1.    ,  0.    ,  0.    ]])

# %%
X_test
# Out:
# array([[ 5.6667, 35.    ,  0.    , ...,  0.    ,  1.    ,  0.    ],
#        [15.    ,  3.    ,  0.    , ...,  1.    ,  0.    ,  0.    ],
#        [17.4167, 35.    ,  0.    , ...,  1.    ,  0.    ,  0.    ],
#        ...,
#        [25.3333, 33.    ,  1.    , ...,  0.    ,  1.    ,  0.    ],
#        [11.1667, 50.    ,  0.    , ...,  1.    ,  0.    ,  0.    ],
#        [24.4167, 36.    ,  0.    , ...,  0.    ,  1.    ,  0.    ]])

# %%
X_train.shape
# Out:
# (302898, 47)

# %%
X_test.shape
# Out:
# (149190, 47)

# %%
y_train.shape
# Out:
# (302898,)

# %%
y_test.shape
# Out:
# (149190,)

# %%
y_train
# Out:
# array([57654,  7008, 10365, ..., 17458, 16394, 14714], dtype=int64)

# %%
y_test
# Out:
# array([ 7180, 12430, 47329, ..., 13178, 12601, 15699], dtype=int64)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)
y_train = scaler.fit_transform(y_train.reshape(-1,1))
y_test_ = scaler.transform(y_test.reshape(-1,1))

# %%
X_test
# Out:
# array([[0.11478686, 0.69387755, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.33268508, 0.04081633, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.38910614, 0.69387755, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.57392963, 0.65306122, 1.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.24319163, 1.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.55253039, 0.71428571, 0.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
X_test.shape
# Out:
# (149190, 47)

# %%
y_train
# Out:
# array([[0.40936764],
#        [0.04141844],
#        [0.06580745],
#        ...,
#        [0.11733893],
#        [0.10960885],
#        [0.09740345]])

# %%
y_test_
# Out:
# array([[0.04266804],
#        [0.08080992],
#        [0.33435529],
#        ...,
#        [0.08624422],
#        [0.08205225],
#        [0.10455959]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation

# %%
model = Sequential()

# %%
# model.add(Dense(units=45, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units=45, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units=45, activation='relu'))
# model.add(Dropout(0.2))
# # model.add(Dense(units=46, activation='relu'))
# # model.add(Dropout(0.2))
# # model.add(Dense(units=46, activation='relu'))
# # model.add(Dropout(0.2))
# model.add(Dense(units=1))
# model.compile(optimizer='adam',loss='mean_squared_error',metrics='mse')

# %%
model.add(Dense(100, input_dim = 47))
model.add(Activation('relu'))
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dense(150))
model.add(Activation('linear'))
model.add(Dense(1))         
model.compile(loss = 'mse', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4800
#
#  activation (Activation)     (None, 100)               0
#
#  dense_1 (Dense)             (None, 150)               15150
#
#  activation_1 (Activation)   (None, 150)               0
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  activation_2 (Activation)   (None, 150)               0
#
#  dense_3 (Dense)             (None, 150)               22650
#
#  activation_3 (Activation)   (None, 150)               0
#
#  dense_4 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 65,401
# Trainable params: 65,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs = 20, batch_size = 20)
# Out:
# Epoch 1/20
# 15145/15145 [==============================] - 82s 5ms/step - loss: 0.0024
# Epoch 2/20
# 15145/15145 [==============================] - 82s 5ms/step - loss: 0.0019
# Epoch 3/20
# 15145/15145 [==============================] - 75s 5ms/step - loss: 0.0018
# Epoch 4/20
# 15145/15145 [==============================] - 79s 5ms/step - loss: 0.0018
# Epoch 5/20
# 15145/15145 [==============================] - 78s 5ms/step - loss: 0.0018
# Epoch 6/20
# 15145/15145 [==============================] - 79s 5ms/step - loss: 0.0017
# Epoch 7/20
# 15145/15145 [==============================] - 78s 5ms/step - loss: 0.0017
# Epoch 8/20
# 15145/15145 [==============================] - 77s 5ms/step - loss: 0.0017
# Epoch 9/20
# 15145/15145 [==============================] - 77s 5ms/step - loss: 0.0017
# Epoch 10/20
# 15145/15145 [==============================] - 80s 5ms/step - loss: 0.0017
# Epoch 11/20
# 15145/15145 [==============================] - 78s 5ms/step - loss: 0.0016
# Epoch 12/20
# 15145/15145 [==============================] - 80s 5ms/step - loss: 0.0016
# Epoch 13/20
# 15145/15145 [==============================] - 75s 5ms/step - loss: 0.0016
# Epoch 14/20
# 15145/15145 [==============================] - 70s 5ms/step - loss: 0.0016
# Epoch 15/20
# 15145/15145 [==============================] - 77s 5ms/step - loss: 0.0016
# Epoch 16/20
# 15145/15145 [==============================] - 77s 5ms/step - loss: 0.0016
# Epoch 17/20
# 15145/15145 [==============================] - 77s 5ms/step - loss: 0.0016
# Epoch 18/20
# 15145/15145 [==============================] - 68s 4ms/step - loss: 0.0016
# Epoch 19/20
# 15145/15145 [==============================] - 78s 5ms/step - loss: 0.0016
# Epoch 20/20
# 15145/15145 [==============================] - 79s 5ms/step - loss: 0.0016

# %%
result = model.evaluate(X_test, y_test_)
accuracy = 1 - result
print(f"Accuracy: {round((accuracy)*100, 3)}%")
# Out:
# 4663/4663 [==============================] - 18s 4ms/step - loss: 0.0015
# Accuracy: 99.847%

# %%
y_org_test = scaler.inverse_transform(y_test_)

# %%
y_org_test
# Out:
# array([[ 7180.],
#        [12430.],
#        [47329.],
#        ...,
#        [13178.],
#        [12601.],
#        [15699.]])

# %%
x_org_test=scaler.inverse_transform(X_test)

# %%
model.predict(X_test)
# Out:
# 4663/4663 [==============================] - 18s 4ms/step
# array([[0.05474524],
#        [0.07044942],
#        [0.3313663 ],
#        ...,
#        [0.08224449],
#        [0.081941  ],
#        [0.11572799]], dtype=float32)

# %%
pred = model.predict(X_test)
# Out:
# 4663/4663 [==============================] - 17s 4ms/step

# %%
pred=scaler.inverse_transform(pred)

# %%
X_org_test = scaler.inverse_transform(X_test)

# %%
X_org_test.shape
# Out:
# (149190, 47)

# %%
pred.shape
# Out:
# (149190, 1)

# %%
y_test_org = scaler.inverse_transform(y_test_)

# %%
y_test_org.shape
# Out:
# (149190, 1)

# %%
y_test_org_flatten = y_test_org.ravel()
pred_flatten = pred.ravel()

# %%
# regression_line = np.polyfit(y_test_org_flatten, pred_flatten, 1)  # Linear regression (degree=1)

# # Create a scatter plot
# plt.scatter(y_test_org_flatten, pred_flatten, label='Actual vs. Predicted')

# # Plot the regression line
# plt.plot(y_test_org_flatten, np.polyval(regression_line, y_test_org_flatten), color='red', label='Regression Line')

# %%
y_test_org_flatten
# Out:
# array([ 7180., 12430., 47329., ..., 13178., 12601., 15699.])

# %%
pred
# Out:
# array([[ 8842.3545],
#        [11003.94  ],
#        [46917.582 ],
#        ...,
#        [12627.461 ],
#        [12585.6875],
#        [17236.264 ]], dtype=float32)

# %%
pred.shape
# Out:
# (149190, 1)

# %%
plt.scatter(y_test_org, pred)

# %%
data_frame = pd.DataFrame({'Actual': y_test_org_flatten, 'Predicted': pred_flatten})

# %%
data_frame
# Out:
#          Actual     Predicted
# 0        7180.0   8842.354492
# 1       12430.0  11003.940430
# 2       47329.0  46917.582031
# 3        6873.0  12171.618164
# 4       21817.0  14227.010742
# ...         ...           ...
# 149185   8867.0  10094.292969
# 149186  45345.0  44926.523438
# 149187  13178.0  12627.460938
# 149188  12601.0  12585.687500
# 149189  15699.0  17236.263672
#
# [149190 rows x 2 columns]

# %% [markdown]
# # Save the model

# %%
model.save('final_model.h5')

# %%
from keras.models import load_model

# %%
final_model = load_model('final_model.h5')

# %% [markdown]
# # Check the prediction

# %%
# model.save('model.h5')

# %%
# from tensorflow.keras.models import load_model

# %%
# model = load_model('model.h5')

# %%
pred=model.predict(X_test)
# Out:
# 4663/4663 [==============================] - 18s 4ms/step

# %%
pred
# Out:
# array([[0.05474524],
#        [0.07044942],
#        [0.3313663 ],
#        ...,
#        [0.08224449],
#        [0.081941  ],
#        [0.11572799]], dtype=float32)

# %%
pred=scaler.inverse_transform(pred)

# %%
pred
# Out:
# array([[ 8842.3545],
#        [11003.94  ],
#        [46917.582 ],
#        ...,
#        [12627.461 ],
#        [12585.6875],
#        [17236.264 ]], dtype=float32)

# %%
scaler.inverse_transform(model.predict(X_test))
# Out:
# 4663/4663 [==============================] - 17s 4ms/step
# array([[ 8842.3545],
#        [11003.94  ],
#        [46917.582 ],
#        ...,
#        [12627.461 ],
#        [12585.6875],
#        [17236.264 ]], dtype=float32)

# %%
import json
import numpy as np

# Example JSON string
json_string = '''
{
    "Duration_in_hours": 1,
    "Days_left": 20,
    "Journey_day_Friday": 1,
    "Journey_day_Monday": 0,
    "Journey_day_Saturday": 0,
    "Journey_day_Sunday": 0,
    "Journey_day_Thursday": 0,
    "Journey_day_Tuesday": 0,
    "Journey_day_Wednesday": 0,
    "Airline_Air_India": 0,
    "Airline_AirAsia": 0,
    "Airline_AkasaAir": 0,
    "Airline_AllianceAir": 0,
    "Airline_GO FIRST": 0,
    "Airline_Indigo": 1,
    "Airline_SpiceJet": 0,
    "Airline_StarAir": 0,
    "Airline_Vistara": 0,
    "Class_Business": 0,
    "Class_Economy": 1,
    "Class_First": 0,
    "Class_Premium_Economy": 0,
    "Source_Ahmedabad": 0,
    "Source_Bangalore": 1,
    "Source_Chennai": 0,
    "Source_Delhi": 0,
    "Source_Hyderabad": 0,
    "Source_Kolkata": 0,
    "Source_Mumbai": 0,
    "Departure_12 PM - 6 PM": 0,
    "Departure_6 AM - 12 PM": 1,
    "Departure_After 6 PM": 0,
    "Departure_Before 6 AM": 0,
    "Total_stops_1-stop": 0,
    "Total_stops_2+-stop": 0,
    "Total_stops_non-stop": 1,
    "Arrival_12 PM - 6 PM": 0,
    "Arrival_6 AM - 12 PM": 1,
    "Arrival_After 6 PM": 0,
    "Arrival_Before 6 AM": 0,
    "Destination_Ahmedabad": 0,
    "Destination_Bangalore": 0,
    "Destination_Chennai": 1,
    "Destination_Delhi": 0,
    "Destination_Hyderabad": 0,
    "Destination_Kolkata": 0,
    "Destination_Mumbai": 0
}
'''

# Load JSON string into a dictionary
data = json.loads(json_string)

# %%
features = pd.DataFrame([data])

# %%
features_X = features.values.reshape(1,-1)

# %% [markdown]
# features_X

# %% [markdown]
# scaler = MinMaxScaler()

# %% [markdown]
# scaler = scaler.fit(X_train)

# %% [markdown]
# scaled_data = scaler.transform(features_X)

# %% [markdown]
# scaled_data

# %% [markdown]
# predictions = final_model.predict(scaled_data)

# %% [markdown]
# predictions

# %%
predictions = final_model.predict(features_X)
# Out:
# 1/1 [==============================] - 0s 65ms/step

# %%
predictions
# Out:
# array([[-0.04328778]], dtype=float32)

# %%
output_scaler = MinMaxScaler()
output_scaler = output_scaler.fit(y_test.reshape(-1,1))  # Fit the output scaler on your training output data

# %%
out_value = output_scaler.inverse_transform(predictions)

# %%
# Your array
original_array = np.array(out_value, dtype=np.float32)

# Access the original value
original_value = original_array[0, 0]

print(" The flight price is ",abs(original_value))
# Out:
#  The flight price is  4730.3726
